# %% [markdown]
# #### **List of uniform instrument names:**
#
# **All names to become 'OS-38'**:\
# 'Ocean Surveyer 38', 'Ocean Surveyor 38'
#
# **All names to become 'OS-75'**:\
# 'Ocean Surveyor 75', 'OS75 narrowband', 'Ocean Surveyer 75', 'Ocean Surveyor 75 narrowband', 'OS75 (Ocean Surveyor)', 'Ocean Surveyor 75 broadband', 'Ocean Surveyor OS75', 'OS75', 'Ocean Surveryor 75', 'Ocean Surveyor 75 narroband', 'Ocean Surveyor 75 Broadband', 'Ocean Surveyor 75 Narrowband', '75KHz Ocean Surveyor narrowband', 'Ocean Surveyor 75 kHz', 'RDI 75KHz Ocean Surveyor', 'Ocean Surveyor 75 kHz Phased Array', '75KHz Ocean Surveyor'
#
# **All names to become 'OS-150'**:\
# 'Ocean Surveyer 150', 'Ocean Surveryor 150', 'Ocean Surveyor 150 narroband', 'Ocean Surveyor 150 narrowband', 'Ocean Surveyor 150 broadband'
#
# **All names to become 'OS-II-38'**:\
# 'Ocean Surveyor II (OS-II 38)'
#
# **All names to become 'OS-II-75'**:\
# 'OSII75S phased-array'
#
# **All names to become 'WH-300'**:\
# 'WorkHorse 300', 'Workhorse 300', 'Workhorse 300; 300 kHz'
#
# **All names to become 'WH-1200'**:\
# 'Workhorse 1200'
#
# **All names to become 'WH-Mariner-300'**:\
# 'Workhorse Mariner (300 kHz)'
#
# **All names to become 'WH-Mariner-600'**:\
# 'WorkHorse Mariner 600'
#
# **All names to become 'DCP4400A'**:\
# 'DCP4400A'
#
# -----Some of the following are mildly annoying b/c no VM/DR/SC:
# **All names to become NB-VM-75:**\
# 'narrowband 75 kHz' (assume VM), 'VM75 narrowband'
#
# -----Some of the following are mildly annoying b/c no VM/DR/SC:
# **All names to become NB-VM-150:**\
# 'Narrowband 150' (assume VM), 'NB 150' (assume VM), '150 narrowband' (assume VM), '150 kHz Narrowband' (assume VM), 'Narrow Band 150Khz' (assume VM), '1) Narrow Band 150 kHz' (assume VM), '150 kHz narrow band' (assume VM), 'VM-150 Narrowband', 'RD-VM150 Narrow band', 'VM-150 (NB)', 'VM-150 narrowband', 'RDI VM150 narrowband', 'RD-VM150 narrowband', 'NB 150 (VM-150-18HP)' (assume 18HP makes no difference)
#
# -----The following are mildly annoying b/c no VM/DR/SC:
# **All names to become NB-VM-300:**\
# 'Narrowband 300' (assume VM), '300 narrow band' (assume VM)
#
# **All names to become NB-DR-150:**\
# 'Direct-Read 150 kHz Narrowband' (HAS ALL SERIAL NUMBERS)
#
# -----The following are mildly annoying b/c no VM/DR/SC:
# **All names to become BB-VM-150:**\
# 'Broadband 150' (assume VM),  'Broad Band 150' (assume VM), '150 kHz broadband' (assume VM), '150 broad band, concave' (assume VM)
#
# -----The following are mildly annoying b/c no BB/NB:
# **All names to become either 'NB-VM-150' or 'BB-VM-150'**:\
# 'VM-150', 'RD-VM150', 'VM150', 'RD-VM0150'
# --> look for bw and rename to BB- or NB- when available
#
# **All names to become either 'NB-VM-300' or 'BB-VM-300'**:\
# 'VM-300', 'RD-VM300'
# --> look for bw and rename to BB- or NB- when available
#
# -----The following are more annoying b/c no VM/DR/SC or BB/NB:
# **All names to become 'UNCLEAR'**:\
# '150' (1990-1998; assume RDI + VM + NB or BB - NOT CODED YET),
# 'RDI' (1985-1993; some give you transmit frequency, w/ those just assume VM + either NB or BB - NOT CODED YET),
# '150 kHz hull mounted ADCP' (1991; assume RDI + VM + NB or BB - NOT CODED YET),
# 'Narrowband' (1994-1996; all 153.6kHz transmit frequency; assume RDI + VM --> NB-VM-150),
# '150 kHz' (1994; assume RDI + VM + NB or BB - NOT CODED YET),
# '153.6 kHz hull mounted ADCP' (2002; assume RDI + maybe OS? - NOT CODED YET)
#
# **Special cases**:\
# 1.) 'RD-VM' (HAS ALL SERIAL NUMBERS, READ TRANSMIT FREQUENCY, TOO - IF 150 THEN VM-150, ETC.) - NOT CODED YET, ALMOST DONE
# 2.) 'VM-150 and VM-300' (CHECKED NC FILES - CAN'T DTMN IF IT'S 150 OR 300 --> DISCARD)
# 3.) 'Vessel-mounted 150 kHz Narrowband'
# (HAS ALL SERIAL NUMBERS; YOU WOULD THINK THIS IS JUST NB-VM-150, BUT IF YOU LOOK MORE CAREFULLY IT PROB MEANS HULL-MOUNTED DIRECT-READ SINCE IT'S GOT CONVEX TRANSDUCER_CONFIG;
# NC FILES 00400-00408_short.nc SHOULD PROB ALL BE DR; EITHER DISCARD OR CHANGE ALL TO DR?) - NOT CODED YET
# 4.) 'Vessel-Mount 150 kHz Narrowband'
# (same description as 3.) above) - NOT CODED YET
# 5.) 'Vessel-mount 150 kHz Narrowband'
# (same description as 3.) above but doesn't have serial numbers) - NOT CODED YET

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
import xarray as xr

# %%
# - Set data path
dpath = '/opt/acoustic-variability/data/'

# %%
# - Set saved out figure path
figpath = '/opt/acoustic-variability/python/figures/'

# %% [markdown]
# # Compile JASADCP metadata

# %% [markdown]
# ## Read JASADCP metadata into df

# %%
fnames = sorted(os.listdir(dpath + 'JASADCP/ncfiles'))

# %%
nc_counter = len(fnames)
hardware_model = [None]*nc_counter
serial_numbers = [None]*nc_counter
transmit_frequency = [None]*nc_counter
phased_array = [None]*nc_counter
cruise_beg_date = [None]*nc_counter
blanking_interval = [None]*nc_counter
bin_length = [None]*nc_counter
transducer_beam_angle = [None]*nc_counter
transmit_pulse_length = [None]*nc_counter
comments = [None]*nc_counter
biomass_dtmn = [None]*nc_counter
geo_region = [None]*nc_counter
chief_scientist = [None]*nc_counter
personnel_charge = [None]*nc_counter
manufacturer = [None]*nc_counter
transducer_config = [None]*nc_counter
depth_range = [None]*nc_counter
num_bins = [None]*nc_counter
ens_avg_intvl = [None]*nc_counter
ss_calc = [None]*nc_counter
project = [None]*nc_counter
nb150 = [None]*nc_counter
nb300 = [None]*nc_counter
bb150 = [None]*nc_counter
bb300 = [None]*nc_counter
beam_width = [None]*nc_counter
all_text = [None]*nc_counter

# %%
ifile = 0
for fname in fnames:
    ncfile = dpath + 'JASADCP/ncfiles/' + fname
    ncnow = xr.open_dataset(ncfile)
    strnow = ncnow.attrs['cruise_sonar_summary']
    # 1.) hardware_model
    hardware_modelnow = re.findall("HARDWARE MODEL *: *((?:\S+ )*\S+)", strnow)
    if hardware_modelnow:
        hardware_model[ifile] = hardware_modelnow[0]
    elif not hardware_modelnow: # if hardware_modelnow is empty
        manufacturernow = re.findall("MANUFACTURER *: *((?:\S+ )*\S+)", strnow)
        if manufacturernow:
            hardware_model[ifile] = manufacturernow[0]
    # 2.) serial_numbers
    serial_numbersnow = re.findall("SERIAL NUMBERS *: *((?:\S+ )*\S+)", strnow)
    if serial_numbersnow:
        serial_numbers[ifile] = serial_numbersnow[0]
    # 3.) transmit_frequency
    transmit_frequencynow = re.findall("TRANSMIT FREQUENCY *: *((?:\S+ )*\S+)", strnow)
    if transmit_frequencynow:
        transmit_frequency[ifile] = transmit_frequencynow[0]
    # 4.) phased_array 
    phased_arraynow = re.findall("phased.array", strnow, re.IGNORECASE)
    if phased_arraynow:
        sep = '///'; phased_arraynow = sep.join(phased_arraynow)
        phased_array[ifile] = phased_arraynow
    # 5.) cruise_beg_date
    cruise_beg_date[ifile] = ncnow['time'][0].values
    # 6.) blanking_interval
    blanking_intervalnow = re.findall("BLANKING INTERVAL *: *((?:\S+ )*\S+)", strnow)
    if blanking_intervalnow:
        blanking_interval[ifile] = blanking_intervalnow[0]
    # 7.) bin_length
    bin_lengthnow = re.findall("BIN LENGTH *: *((?:\S+ )*\S+)", strnow)
    if bin_lengthnow:
        bin_length[ifile] = bin_lengthnow[0]
    # 8.) transducer_beam_angle
    transducer_beam_anglenow = re.findall("TRANSDUCER BEAM ANGLE *: *((?:\S+ )*\S+)", strnow)
    if transducer_beam_anglenow:
        transducer_beam_angle[ifile] = transducer_beam_anglenow[0]
    # 9.) transmit_pulse_length
    transmit_pulse_lengthnow = re.findall("TRANSMIT PULSE LENGTH *: *((?:\S+ )*\S+)", strnow)
    if transmit_pulse_lengthnow:
        transmit_pulse_length[ifile] = transmit_pulse_lengthnow[0]
    # 10.) comments
    commentsnow = re.findall("COMMENTS *: *((?:\S+ )*\S+)", strnow)
    if commentsnow:
        sep = '///'; commentsnow = sep.join(commentsnow)
        comments[ifile] = commentsnow
    # 11.) biomass_dtmn
    biomass_dtmnnow = re.findall("BIOMASS DETERMINATION *: *((?:\S+ )*\S+)", strnow)
    if biomass_dtmnnow:
        biomass_dtmn[ifile] = biomass_dtmnnow[0]
    # 12.) geo_region
    geo_regionnow = re.findall("GEOGRAPHIC_REGION *: *((?:\S+ )*\S+)", strnow)
    if geo_regionnow:
        geo_region[ifile] = geo_regionnow[0]
    # 13.) chief_scientist
    chief_scientistnow = re.findall("CHIEF SCIENTIST ON SHIP *: *((?:\S+ )*\S+)", strnow)
    if chief_scientistnow:
        chief_scientist[ifile] = chief_scientistnow[0]
    # 14.) personnel_charge
    personnel_chargenow = re.findall("PERSONNEL IN CHARGE *: *((?:\S+ )*\S+)", strnow)
    if personnel_chargenow:
        personnel_charge[ifile] = personnel_chargenow[0]
    # 15.) manufacturer
    manufacturernow = re.findall("MANUFACTURER *: *((?:\S+ )*\S+)", strnow)
    if manufacturernow:
        manufacturer[ifile] = manufacturernow[0]
    # 16.) transducer_config
    transducer_confignow = re.findall("TRANSDUCER CONFIGURATION *: *((?:\S+ )*\S+)", strnow)
    if transducer_confignow:
        transducer_config[ifile] = transducer_confignow[0]
    # 17.) depth_range
    depth_rangenow = re.findall("DEPTH RANGE *: *((?:\S+ )*\S+)", strnow)
    if depth_rangenow:
        depth_range[ifile] = depth_rangenow[0]
    # 18.) num_bins
    num_binsnow = re.findall("NUMBER OF BINS *: *((?:\S+ )*\S+)", strnow)
    if num_binsnow:
        num_bins[ifile] = num_binsnow[0]
    # 19.) ens_avg_intvl
    ens_avg_intvlnow = re.findall("ENSEMBLE AVERAGING INTERVAL *: *((?:\S+ )*\S+)", strnow)
    if ens_avg_intvlnow:
        ens_avg_intvl[ifile] = ens_avg_intvlnow[0]
    # 20.) ss_calc
    ss_calcnow = re.findall("SOUND SPEED CALCULATION *: *((?:\S+ )*\S+)", strnow)
    if ss_calcnow:
        ss_calc[ifile] = ss_calcnow[0]
    # 21.) project
    projectnow = re.findall("PROJECT *: *((?:\S+ )*\S+)", strnow)
    if projectnow:
        project[ifile] = projectnow[0]
    # 22.) nb150
    nb150now = re.findall("nb150", strnow, re.IGNORECASE)
    if nb150now:
        sep = '///'; nb150now = sep.join(nb150now)
        nb150[ifile] = nb150now
    # 23.) nb300
    nb300now = re.findall("nb300", strnow, re.IGNORECASE)
    if nb300now:
        sep = '///'; nb300now = sep.join(nb300now)
        nb300[ifile] = nb300now
    # 22.) bb150
    bb150now = re.findall("bb150", strnow, re.IGNORECASE)
    if bb150now:
        sep = '///'; bb150now = sep.join(bb150now)
        bb150[ifile] = bb150now
    # 23.) bb300
    bb300now = re.findall("bb300", strnow, re.IGNORECASE)
    if bb300now:
        sep = '///'; bb300now = sep.join(bb300now)
        bb300[ifile] = bb300now
    # 24.) beam_width
    beam_widthnow = re.findall("ACOUSTIC BEAM WIDTH *: *((?:\S+ )*\S+)", strnow)
    if beam_widthnow:
        beam_width[ifile] = beam_widthnow[0]
    # 25.) all_text
    all_text[ifile] = strnow
    ifile = ifile+1

# %%
df = pd.concat([pd.Series(fnames,name='fname'),
     pd.Series(hardware_model,name='hardware_model'),pd.Series(serial_numbers,name='serial_numbers'),
     pd.Series(transmit_frequency,name='transmit_frequency'),pd.Series(phased_array,name='phased_array'),
     pd.Series(cruise_beg_date,name='cruise_beg_date'),pd.Series(blanking_interval,name='blanking_interval'),
     pd.Series(bin_length,name='bin_length'),pd.Series(transducer_beam_angle,name='transducer_beam_angle'),
     pd.Series(transmit_pulse_length,name='transmit_pulse_length'),pd.Series(comments,name='comments'),
     pd.Series(biomass_dtmn,name='biomass_dtmn'),pd.Series(geo_region,name='geo_region'),
     pd.Series(chief_scientist,name='chief_scientist'),pd.Series(personnel_charge,name='personnel_charge'),
     pd.Series(manufacturer,name='manufacturer'),pd.Series(transducer_config,name='transducer_config'),
     pd.Series(depth_range,name='depth_range'),pd.Series(num_bins,name='num_bins'),
     pd.Series(ens_avg_intvl,name='ens_avg_intvl'),pd.Series(ss_calc,name='ss_calc'),
     pd.Series(project,name='project'),pd.Series(nb150,name='nb150'),
     pd.Series(nb300,name='nb300'),pd.Series(bb150,name='bb150'),
     pd.Series(bb300,name='bb300'),pd.Series(beam_width,name='beam_width'),
     pd.Series(all_text,name='all_text')],
    axis=1)

# %%
# - Define fxns to describe bandwidth from comments, hardware_model, and transmit_frequency 

# --> Checks for hardware_model names containing NB = narrowband
#dfnow = df.dropna(subset=['hardware_model'])
#dfnow[dfnow['hardware_model'].str.contains('NB')]['hardware_model'].unique()
# --> Results are:
# array(['NB 150 (VM-150-18HP)', 'NB 150', 'VM-150 (NB)'], dtype=object)

def set_bandwidth_from_all_text(row):
# copy-pasted from set_bandwidth_from_comments, but change to all
# I use "broadband" instead of "broad" here b/c we have some cruise comments that say "broad-scale"
    if row['all_text']:
        if   ( (re.search('broadband', row['all_text'], re.IGNORECASE) or
                re.search('broad band', row['all_text'], re.IGNORECASE))
                and
               (re.search('narro', row['all_text'], re.IGNORECASE) or
                re.search('nb75', row['all_text'], re.IGNORECASE) or
                re.search('nb150', row['all_text'], re.IGNORECASE) or
                re.search('nb300', row['all_text'], re.IGNORECASE) or
                re.search('nb600', row['all_text'], re.IGNORECASE) or
                re.search('nb1200', row['all_text'], re.IGNORECASE))
             ):
            return 'both broad and narrowband?' 
        elif (re.search('broadband', row['all_text'], re.IGNORECASE) or
              re.search('broad band', row['all_text'], re.IGNORECASE)
             ):
            return 'broadband'
        elif (re.search('narro', row['all_text'], re.IGNORECASE) or
              re.search('nb75', row['all_text'], re.IGNORECASE) or
              re.search('nb150', row['all_text'], re.IGNORECASE) or
              re.search('nb300', row['all_text'], re.IGNORECASE) or
              re.search('nb600', row['all_text'], re.IGNORECASE) or
              re.search('nb1200', row['all_text'], re.IGNORECASE)
             ):
            return 'narrowband'
        else:
            return None
    else:
        return None

def set_bandwidth_from_comments(row):
# I use "broadband" instead of "broad" here b/c we have some cruise comments that say "broad-scale"
    if row['comments']:
        if (re.search('broadband', row['comments'], re.IGNORECASE) and
                re.search('narro', row['comments'], re.IGNORECASE)):
            return 'both broad and narrowband?' 
        elif re.search('broadband', row['comments'], re.IGNORECASE):
            return 'broadband'
        elif re.search('narro', row['comments'], re.IGNORECASE):
            return 'narrowband'
        else:
            return None
    else:
        return None
    
def set_bandwidth_from_hardware_model(row):
    if row['hardware_model']:
        if re.search('broad', row['hardware_model'], re.IGNORECASE):
            return 'broadband'
        elif (re.search('narro', row['hardware_model'], re.IGNORECASE) or
                re.search('nb', row['hardware_model'], re.IGNORECASE)):
            return 'narrowband'
        else:
            return None
    else:
        return None

def set_bandwidth_from_transmit_frequency(row):
    if row['transmit_frequency']:
        if re.search('broadband', row['transmit_frequency'], re.IGNORECASE):
            return 'broadband'
        elif re.search('narro', row['transmit_frequency'], re.IGNORECASE):
            return 'narrowband'
        else:
            return None
    else:
        return None
    
def set_final_bandwidth(row):
    lsnow = [row['bw_from_comments'],row['bw_from_hardware_model'],row['bw_from_transmit_frequency']]
    idxnow = [i for i,lsitem in enumerate(lsnow) if lsitem != None]
    if len(idxnow)>0:
        if len(idxnow)==3:
            if lsnow[1]!=lsnow[2]:
                return 'CHECK NC FILE'
            else:
                return lsnow[2]
        elif len(idxnow)==2:
            if idxnow==[0,1]:
            # prioritize bw_from_hardware_model over bw_from_comments
                return lsnow[1]
            elif idxnow==[0,2]:
            # prioritize bw_from_transmit_frequency over bw_from_comments
                return lsnow[2]
            elif (idxnow==[1,2]) and (lsnow[1]==lsnow[2]):
                return lsnow[2]
            elif (idxnow==[1,2]) and (lsnow[1]!=lsnow[2]):
            # equal priority for bw_from_transmit_frequency and bw_from_hardware_model
                return 'CHECK NC FILE'            
        elif len(idxnow)==1:
            return lsnow[idxnow[0]]
    else:
        return None

# %%
df['bw_from_all_text']=df.apply(set_bandwidth_from_all_text, axis=1)
df['bw_from_comments']=df.apply(set_bandwidth_from_comments, axis=1)
df['bw_from_hardware_model']=df.apply(set_bandwidth_from_hardware_model, axis=1)
df['bw_from_transmit_frequency']=df.apply(set_bandwidth_from_transmit_frequency, axis=1)
df['bandwidth']=df.apply(set_final_bandwidth, axis=1)
# - Testing (old as of 1/28/20)
#pd.set_option('max_rows', 500)
#pd.set_option('display.max_colwidth', -1)
#df[df['bw_from_comments']=='narrowband'][['hardware_model','transmit_frequency','bw_from_comments','bw_from_hardware_model','bw_from_transmit_frequency','bandwidth','comments']]
# also looked at: ['bw_from_comments']=='broadband', ['bw_from_hardware_model']=='narrowband',
# ['bw_from_hardware_model']=='broadband', ['bw_from_transmit_frequency']=='narrowband',
# ['bw_from_hardware_model']=='broadband', ['bandwidth']=='CHECK NC FILE'
# --> I CHECKED ALL PRINTED OUT ROWS AND ALL GOT THE RIGHT ANSWER IN THE 
# FINAL COLUMN NAMED 'bandwidth'; ALSO no files triggered the 'CHECK NC FILE'
# designation in the 'bandwidth' column, yay!

# %%
#df[(df['nb150'].notnull()) & ~(df['bandwidth'].notnull())
#  ][['hardware_model','nb150','nb300','bb150','bb300','bw_from_all_text','bandwidth']]
# --> lots of them

#df[(df['nb300'].notnull()) & ~(df['bandwidth'].notnull())
#  ][['hardware_model','nb150','nb300','bb150','bb300','bw_from_all_text','bandwidth']]
# --> none

#df[(df['bb300'].notnull()) & ~(df['bandwidth'].notnull())
#  ][['hardware_model','nb150','nb300','bb150','bb300','bw_from_all_text','bandwidth']]
# --> none

#df[(df['bb150'].notnull()) & ~(df['bandwidth'].notnull())
#  ][['hardware_model','nb150','nb300','bb150','bb300','bw_from_all_text','bandwidth']]
# --> none

# %%
pd.set_option('display.max_colwidth', 200)
df[df['beam_width'].notnull()]['beam_width']
# Out:
# 4                     3 deg (???)
# 77                  not specified
# 78                  not specified
# 109     unconfirmed (narrow band)
# 110     unconfirmed (narrow band)
# 111     unconfirmed (narrow band)
# 112     unconfirmed (narrow band)
# 113     unconfirmed (narrow band)
# 114     unconfirmed (narrow band)
# 115     unconfirmed (narrow band)
# 120                    not listed
# 292                      unknown:
# 296                      unknown:
# 297                      unknown:
# 298                      unknown:
# 303                 not specified
# 304                 not specified
# 346                 not specified
# 347                 not specified
# 348                 not specified
# 349                 not specified
# 350                 not specified
# 351                 not specified
# 396                    not listed
# 397                    not listed
# 398                    not listed
# 420                 not specified
# 422                 not specified
# 423                 not specified
# 424                 not specified
# 440                 not specified
# 474                 not specified
# 475                 not specified
# 476                 not specified
# 477                 not specified
# 510                 not specified
# 591                      unknown:
# 779                    30 degrees
# 1162                   30 degrees
# 1164                   30 degrees
# 1166                   30 degrees
# 1168                   30 degrees
# 1170                   30 degrees
# 1172                   30 degrees
# 1175                   30 degrees
# 1177                   30 degrees
# 1179                   30 degrees
# 1181                   30 degrees
# 1185                   30 degrees
# 1187                   30 degrees
# 1189                   30 degrees
# 1192                   30 degrees
# 1201                   30 degrees
# 1206                   30 degrees
# 1209                   30 degrees
# 1212                   30 degrees
# 1215                   30 degrees
# 1218                   30 degrees
# 1373                   30 degrees
# Name: beam_width, dtype: object

# %%
# CONTINUE HERE!!!!!!
pd.set_option('max_rows', 2200)
#pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_colwidth', 20)
dfnow = df[(df['bw_from_all_text']=='both broad and narrowband?') &
           ~(df['bw_from_hardware_model'].notnull()) &
           ~(df['bw_from_transmit_frequency'].notnull()) &
           ~(df['bw_from_comments'].notnull()) &
           ~(df['beam_width'].notnull()) #&
           #(df.index>2134)
  ][['hardware_model','transmit_frequency','fname','cruise_beg_date','beam_width',
     'bw_from_all_text','bw_from_comments','bw_from_hardware_model',
     'bw_from_transmit_frequency','bandwidth','comments']]
print(len(dfnow))
dfnow
# - broadband from all_text
#--> the 1 file came up b/c of "broadband seismograph"
#--> not real :(
# - narrowband from all_text
#--> 174 total
#--> 00014_short not narrowband, just had the phrase narrow time period
#    ...require "narrowband" or "narrow band"
#--> 00090-00095_short not narrowband, just had some place Narrows 
#    ...require "narrowband" or "narrow band"
#--> 00111-00117_short IS narrowband, "narrow band" from ACOUSTIC BEAM WIDTH so added beam_width.notnull()
#    ...the above is now in this set anymore then (now will be <174 total)
#    ...add beam_width as criteria above comments and all_text
#--> 00544-00545_short not narrowband, narrow channel/narrowly-spaced
#    ...require "narrowband" or "narrow band"
#--> 00803-00805_short IS narrowband, NB150 in next-line comments
#--> 00900-00923_short not narrowband, just had some place Narrows and maybe other phrases
#    ...require "narrowband" or "narrow band"
#--> 01285,7,9_short IS narrowband, NB150 in next-line comments
#--> 01340-01435(skipping every other ish)_short IS narrowband, NB150 in next-line comments
#--> 01527-8_short IS narrowband, nb150 from CRUISE_NAME
#--> 01567_short IS narrowband, nb150 from CRUISE_NAME
#--> 01574-01760(skipping every other ish)_short IS narrowband, nb150 from CRUISE_NAME, NB150 in next-line comments and ATTACHMENT TO THE HULL
#--> 01814-6_short IS narrowband, "narrowband mode" from COMMENT (no S! UGH)
#--> 01987-02159(skipping every other ish)_short IS narrowband, nb150 from CRUISE_NAME, NB150 in next-line comments and ATTACHMENT TO THE HULL
#--> 02161_short IS narrowband, "75 kHz narrowband" from COMMENT (no S! UGH) 
#--> 02172-02253(skipping every other ish)_short IS narrowband, nb150 from CRUISE_NAME, NB150 in next-line comments and ATTACHMENT TO THE HULL
#--> 02355-68_short not narrowband, just had some place Narrows 
#    ...require "narrowband" or "narrow band"
# Out:
# 143
#          hardware_model transmit_frequency           fname  \
# 875       WorkHorse 300             300kHz  00925_short.nc
# 877       WorkHorse 300             300kHz  00927_short.nc
# 880       WorkHorse 300             300kHz  00930_short.nc
# 895       WorkHorse 300             300kHz  00945_short.nc
# 898       WorkHorse 300             300kHz  00948_short.nc
# 932       WorkHorse 300             300kHz  00982_short.nc
# 935       WorkHorse 300             300kHz  00985_short.nc
# 1030             VM-150          153.6 kHz  01087_short.nc
# 1033             VM-150          153.6 kHz  01090_short.nc
# 1036             VM-150          153.6 kHz  01093_short.nc
# 1039             VM-150          153.6 kHz  01096_short.nc
# 1080      WorkHorse 300             300kHz  01137_short.nc
# 1083      WorkHorse 300             300kHz  01140_short.nc
# 1086      WorkHorse 300             300kHz  01143_short.nc
# 1089      WorkHorse 300             300kHz  01146_short.nc
# 1092      WorkHorse 300             300kHz  01149_short.nc
# 1095      WorkHorse 300             300kHz  01152_short.nc
# 1098      WorkHorse 300             300kHz  01155_short.nc
# 1101      WorkHorse 300             300kHz  01158_short.nc
# 1105      WorkHorse 300             300kHz  01162_short.nc
# 1108      WorkHorse 300             300kHz  01165_short.nc
# 1111      WorkHorse 300             300kHz  01168_short.nc
# 1116      WorkHorse 300             300kHz  01173_short.nc
# 1119      WorkHorse 300             300kHz  01176_short.nc
# 1122      WorkHorse 300             300kHz  01179_short.nc
# 1125      WorkHorse 300             300kHz  01182_short.nc
# 1128      WorkHorse 300             300kHz  01185_short.nc
# 1131      WorkHorse 300             300kHz  01188_short.nc
# 1134      WorkHorse 300             300kHz  01191_short.nc
# 1190      WorkHorse 300             300kHz  01247_short.nc
# 1193      WorkHorse 300             300kHz  01250_short.nc
# 1195      WorkHorse 300             300kHz  01252_short.nc
# 1197      WorkHorse 300             300kHz  01254_short.nc
# 1199      WorkHorse 300             300kHz  01256_short.nc
# 1204      WorkHorse 300             300kHz  01261_short.nc
# 1207      WorkHorse 300             300kHz  01264_short.nc
# 1210      WorkHorse 300             300kHz  01267_short.nc
# 1213      WorkHorse 300             300kHz  01270_short.nc
# 1216      WorkHorse 300             300kHz  01273_short.nc
# 1219      WorkHorse 300             300kHz  01276_short.nc
# 1234             VM-150               None  01291_short.nc
# 1256             VM-150          153.6 kHz  01325_short.nc
# 1259             VM-150          153.6 kHz  01328_short.nc
# 1262             VM-150          153.6 kHz  01331_short.nc
# 1265             VM-150          153.6 kHz  01334_short.nc
# 1268             VM-150          153.6 kHz  01337_short.nc
# 1361             VM-150          153.6 kHz  01430_short.nc
# 1374      WorkHorse 300             300kHz  01447_short.nc
# 1379      WorkHorse 300             300kHz  01452_short.nc
# 1382      WorkHorse 300             300kHz  01455_short.nc
# 1385      WorkHorse 300             300kHz  01458_short.nc
# 1388      WorkHorse 300             300kHz  01461_short.nc
# 1391      WorkHorse 300             300kHz  01464_short.nc
# 1394      WorkHorse 300             300kHz  01467_short.nc
# 1397      WorkHorse 300             300kHz  01470_short.nc
# 1400      WorkHorse 300             300kHz  01473_short.nc
# 1403      WorkHorse 300             300kHz  01476_short.nc
# 1406      WorkHorse 300             300kHz  01479_short.nc
# 1409      WorkHorse 300             300kHz  01482_short.nc
# 1412      WorkHorse 300             300kHz  01485_short.nc
# 1415      WorkHorse 300             300kHz  01488_short.nc
# 1418      WorkHorse 300             300kHz  01491_short.nc
# 1421      WorkHorse 300             300kHz  01494_short.nc
# 1426      WorkHorse 300             300kHz  01499_short.nc
# 1429      WorkHorse 300             300kHz  01502_short.nc
# 1435      WorkHorse 300             300kHz  01508_short.nc
# 1441      WorkHorse 300             300kHz  01514_short.nc
# 1444      WorkHorse 300             300kHz  01517_short.nc
# 1447      WorkHorse 300             300kHz  01520_short.nc
# 1469      WorkHorse 300             300kHz  01542_short.nc
# 1473      WorkHorse 300             300kHz  01557_short.nc
# 1476      WorkHorse 300             300kHz  01560_short.nc
# 1487      WorkHorse 300             300kHz  01571_short.nc
# 1518      WorkHorse 300             300kHz  01602_short.nc
# 1521      WorkHorse 300             300kHz  01605_short.nc
# 1545      WorkHorse 300             300kHz  01629_short.nc
# 1550      WorkHorse 300             300kHz  01634_short.nc
# 1553      WorkHorse 300             300kHz  01637_short.nc
# 1556      WorkHorse 300             300kHz  01640_short.nc
# 1559      WorkHorse 300             300kHz  01643_short.nc
# 1562      WorkHorse 300             300kHz  01646_short.nc
# 1565      WorkHorse 300             300kHz  01649_short.nc
# 1568      WorkHorse 300             300kHz  01652_short.nc
# 1571      WorkHorse 300             300kHz  01655_short.nc
# 1574      WorkHorse 300             300kHz  01658_short.nc
# 1577      WorkHorse 300             300kHz  01661_short.nc
# 1580      WorkHorse 300             300kHz  01664_short.nc
# 1604             VM-150          153.6 kHz  01688_short.nc
# 1637      WorkHorse 300             300kHz  01721_short.nc
# 1653             VM-150          153.6 kHz  01737_short.nc
# 1696      WorkHorse 300             300kHz  01780_short.nc
# 1699      WorkHorse 300             300kHz  01783_short.nc
# 1721      WorkHorse 300             300kHz  01811_short.nc
# 1729      WorkHorse 300             300kHz  01819_short.nc
# 1732      WorkHorse 300             300kHz  01822_short.nc
# 1735      WorkHorse 300             300kHz  01825_short.nc
# 1738      WorkHorse 300             300kHz  01828_short.nc
# 1741      WorkHorse 300             300kHz  01831_short.nc
# 1744      WorkHorse 300             300kHz  01834_short.nc
# 1747      WorkHorse 300             300kHz  01837_short.nc
# 1750      WorkHorse 300             300kHz  01840_short.nc
# 1753      WorkHorse 300             300kHz  01843_short.nc
# 1756      WorkHorse 300             300kHz  01846_short.nc
# 1759      WorkHorse 300             300kHz  01849_short.nc
# 1762      WorkHorse 300             300kHz  01852_short.nc
# 1765      WorkHorse 300             300kHz  01855_short.nc
# 1778      WorkHorse 300             300kHz  01868_short.nc
# 1781      WorkHorse 300             300kHz  01871_short.nc
# 1784      WorkHorse 300             300kHz  01874_short.nc
# 1787      WorkHorse 300             300kHz  01877_short.nc
# 1802      WorkHorse 300             300kHz  01892_short.nc
# 1804      WorkHorse 300             300kHz  01894_short.nc
# 1818      WorkHorse 300             300kHz  01909_short.nc
# 1822      WorkHorse 300             300kHz  01913_short.nc
# 1825      WorkHorse 300             300kHz  01916_short.nc
# 1828      WorkHorse 300             300kHz  01919_short.nc
# 1831      WorkHorse 300             300kHz  01922_short.nc
# 1834      WorkHorse 300             300kHz  01925_short.nc
# 1837      WorkHorse 300             300kHz  01928_short.nc
# 1840      WorkHorse 300             300kHz  01931_short.nc
# 1847      WorkHorse 300             300kHz  01938_short.nc
# 1852      WorkHorse 300             300kHz  01943_short.nc
# 1855      WorkHorse 300             300kHz  01946_short.nc
# 1858      WorkHorse 300             300kHz  01949_short.nc
# 1861      WorkHorse 300             300kHz  01952_short.nc
# 1864      WorkHorse 300             300kHz  01955_short.nc
# 1867      WorkHorse 300             300kHz  01958_short.nc
# 1870      WorkHorse 300             300kHz  01961_short.nc
# 1964      WorkHorse 300            300 kHz  02076_short.nc
# 1967      Workhorse 300            300 kHz  02079_short.nc
# 1970      Workhorse 300            300 kHz  02082_short.nc
# 1973      Workhorse 300            300 kHz  02085_short.nc
# 1979      Workhorse 300            300 kHz  02092_short.nc
# 1985      Workhorse 300            300 kHz  02098_short.nc
# 1993             VM-150          153.6 kHz  02106_short.nc
# 2009      Workhorse 300            300 kHz  02122_short.nc
# 2014  Ocean Surveyor 75               None  02127_short.nc
# 2067             VM-150          153.6 kHz  02180_short.nc
# 2225      WorkHorse 300             300kHz  02348_short.nc
# 2228      WorkHorse 300             300kHz  02351_short.nc
# 2231      WorkHorse 300             300kHz  02354_short.nc
# 2261      Workhorse 300            300 kHz  02384_short.nc
# 2264      Workhorse 300            300 kHz  02387_short.nc
#
#           cruise_beg_date beam_width     bw_from_all_text bw_from_comments  \
# 875  2005-05-21 03:06:...       None  both broad and n...             None
# 877  2005-06-13 20:16:...       None  both broad and n...             None
# 880  2005-09-08 19:30:...       None  both broad and n...             None
# 895  2005-03-24 09:50:...       None  both broad and n...             None
# 898  2005-04-30 00:37:...       None  both broad and n...             None
# 932  2005-09-15 17:50:...       None  both broad and n...             None
# 935  2005-10-06 18:40:...       None  both broad and n...             None
# 1030 2004-11-07 09:22:...       None  both broad and n...             None
# 1033 2004-11-24 07:32:...       None  both broad and n...             None
# 1036 2004-12-30 12:43:...       None  both broad and n...             None
# 1039 2005-02-12 11:17:...       None  both broad and n...             None
# 1080 2006-01-23 19:28:...       None  both broad and n...             None
# 1083 2006-02-13 20:32:...       None  both broad and n...             None
# 1086 2006-03-08 19:03:...       None  both broad and n...             None
# 1089 2006-03-31 19:01:...       None  both broad and n...             None
# 1092 2006-05-24 23:33:...       None  both broad and n...             None
# 1095 2006-06-12 18:01:...       None  both broad and n...             None
# 1098 2006-07-11 19:13:...       None  both broad and n...             None
# 1101 2006-08-07 15:42:...       None  both broad and n...             None
# 1105 2006-10-18 11:26:...       None  both broad and n...             None
# 1108 2006-11-08 02:07:...       None  both broad and n...             None
# 1111 2006-12-08 18:03:...       None  both broad and n...             None
# 1116 2007-05-03 19:09:...       None  both broad and n...             None
# 1119 2007-06-08 19:51:...       None  both broad and n...             None
# 1122 2007-07-06 19:28:...       None  both broad and n...             None
# 1125 2007-08-02 19:02:...       None  both broad and n...             None
# 1128 2007-09-01 18:47:...       None  both broad and n...             None
# 1131 2007-11-30 18:57:...       None  both broad and n...             None
# 1134 2007-12-19 19:02:...       None  both broad and n...             None
# 1190 2005-04-05 03:58:...       None  both broad and n...             None
# 1193 2005-05-14 21:39:...       None  both broad and n...             None
# 1195 2005-05-24 22:16:...       None  both broad and n...             None
# 1197 2005-05-27 22:32:...       None  both broad and n...             None
# 1199 2005-06-02 20:21:...       None  both broad and n...             None
# 1204 2005-11-10 18:45:...       None  both broad and n...             None
# 1207 2006-10-04 05:49:...       None  both broad and n...             None
# 1210 2007-01-04 00:42:...       None  both broad and n...             None
# 1213 2007-04-27 07:36:...       None  both broad and n...             None
# 1216 2008-03-10 16:53:...       None  both broad and n...             None
# 1219 2008-05-13 16:25:...       None  both broad and n...             None
# 1234 2006-10-13 01:00:...       None  both broad and n...             None
# 1256 2005-03-16 04:50:...       None  both broad and n...             None
# 1259 2005-04-03 04:19:...       None  both broad and n...             None
# 1262 2005-04-21 13:25:...       None  both broad and n...             None
# 1265 2005-05-19 02:56:...       None  both broad and n...             None
# 1268 2005-06-14 11:33:...       None  both broad and n...             None
# 1361 2007-10-09 10:18:...       None  both broad and n...             None
# 1374 2008-07-01 18:52:...       None  both broad and n...             None
# 1379 2008-01-28 18:12:...       None  both broad and n...             None
# 1382 2008-02-22 17:24:...       None  both broad and n...             None
# 1385 2008-05-26 18:55:...       None  both broad and n...             None
# 1388 2008-06-24 19:01:...       None  both broad and n...             None
# 1391 2008-07-26 01:30:...       None  both broad and n...             None
# 1394 2008-08-15 17:40:...       None  both broad and n...             None
# 1397 2008-10-09 19:37:...       None  both broad and n...             None
# 1400 2008-11-29 19:30:...       None  both broad and n...             None
# 1403 2008-12-15 18:55:...       None  both broad and n...             None
# 1406 2009-07-23 17:48:...       None  both broad and n...             None
# 1409 2009-08-18 00:32:...       None  both broad and n...             None
# 1412 2010-07-07 18:13:...       None  both broad and n...             None
# 1415 2010-08-06 19:07:...       None  both broad and n...             None
# 1418 2010-09-02 20:10:...       None  both broad and n...             None
# 1421 2010-10-02 18:05:...       None  both broad and n...             None
# 1426 2009-01-19 19:42:...       None  both broad and n...             None
# 1429 2009-02-16 18:54:...       None  both broad and n...             None
# 1435 2009-07-02 18:08:...       None  both broad and n...             None
# 1441 2011-01-08 19:39:...       None  both broad and n...             None
# 1444 2011-01-27 18:38:...       None  both broad and n...             None
# 1447 2011-02-27 18:37:...       None  both broad and n...             None
# 1469 2011-04-10 18:32:...       None  both broad and n...             None
# 1473 2011-09-24 18:59:...       None  both broad and n...             None
# 1476 2011-07-18 19:08:...       None  both broad and n...             None
# 1487 2012-02-08 19:25:...       None  both broad and n...             None
# 1518 2012-04-17 00:00:...       None  both broad and n...             None
# 1521 2012-03-24 13:36:...       None  both broad and n...             None
# 1545 2009-05-22 13:33:...       None  both broad and n...             None
# 1550 2008-03-25 20:55:...       None  both broad and n...             None
# 1553 2008-08-26 00:26:...       None  both broad and n...             None
# 1556 2008-09-08 15:06:...       None  both broad and n...             None
# 1559 2008-09-25 14:29:...       None  both broad and n...             None
# 1562 2010-01-30 17:43:...       None  both broad and n...             None
# 1565 2010-02-01 16:05:...       None  both broad and n...             None
# 1568 2010-02-20 18:22:...       None  both broad and n...             None
# 1571 2010-04-15 21:22:...       None  both broad and n...             None
# 1574 2010-04-29 01:15:...       None  both broad and n...             None
# 1577 2010-06-29 17:44:...       None  both broad and n...             None
# 1580 2010-11-23 19:38:...       None  both broad and n...             None
# 1604 2009-02-12 06:27:...       None  both broad and n...             None
# 1637 2012-08-15 19:22:...       None  both broad and n...             None
# 1653 2010-11-26 05:37:...       None  both broad and n...             None
# 1696 2013-03-21 12:11:...       None  both broad and n...             None
# 1699 2013-05-08 17:08:...       None  both broad and n...             None
# 1721 2010-06-17 19:43:...       None  both broad and n...             None
# 1729 2011-02-01 18:53:...       None  both broad and n...             None
# 1732 2011-11-08 15:52:...       None  both broad and n...             None
# 1735 2010-04-01 22:27:...       None  both broad and n...             None
# 1738 2010-05-16 01:20:...       None  both broad and n...             None
# 1741 2010-11-10 23:12:...       None  both broad and n...             None
# 1744 2010-12-09 03:57:...       None  both broad and n...             None
# 1747 2011-10-01 17:45:...       None  both broad and n...             None
# 1750 2011-10-28 18:21:...       None  both broad and n...             None
# 1753 2011-12-06 08:20:...       None  both broad and n...             None
# 1756 2012-04-07 18:10:...       None  both broad and n...             None
# 1759 2012-04-19 22:09:...       None  both broad and n...             None
# 1762 2012-05-13 19:43:...       None  both broad and n...             None
# 1765 2012-10-12 23:16:...       None  both broad and n...             None
# 1778 2010-10-15 10:40:...       None  both broad and n...             None
# 1781 2010-11-08 17:32:...       None  both broad and n...             None
# 1784 2011-11-06 14:22:...       None  both broad and n...             None
# 1787 2011-12-13 11:04:...       None  both broad and n...             None
# 1802 2009-09-06 16:02:...       None  both broad and n...             None
# 1804 2010-03-05 18:08:...       None  both broad and n...             None
# 1818 2011-08-27 17:36:...       None  both broad and n...             None
# 1822 2011-12-18 19:16:...       None  both broad and n...             None
# 1825 2012-03-23 20:11:...       None  both broad and n...             None
# 1828 2012-06-25 20:01:...       None  both broad and n...             None
# 1831 2012-07-30 18:49:...       None  both broad and n...             None
# 1834 2012-08-16 17:45:...       None  both broad and n...             None
# 1837 2012-09-13 17:43:...       None  both broad and n...             None
# 1840 2012-10-06 17:46:...       None  both broad and n...             None
# 1847 2013-03-05 17:29:...       None  both broad and n...             None
# 1852 2013-05-16 17:34:...       None  both broad and n...             None
# 1855 2013-06-24 17:38:...       None  both broad and n...             None
# 1858 2013-09-10 18:14:...       None  both broad and n...             None
# 1861 2013-09-30 18:14:...       None  both broad and n...             None
# 1864 2013-10-26 17:47:...       None  both broad and n...             None
# 1867 2013-11-25 17:45:...       None  both broad and n...             None
# 1870 2013-12-19 18:36:...       None  both broad and n...             None
# 1964 2014-01-14 19:09:...       None  both broad and n...             None
# 1967 2014-02-13 18:54:...       None  both broad and n...             None
# 1970 2014-03-04 21:07:...       None  both broad and n...             None
# 1973 2014-04-09 18:46:...       None  both broad and n...             None
# 1979 2014-09-13 18:54:...       None  both broad and n...             None
# 1985 2014-11-20 18:59:...       None  both broad and n...             None
# 1993 2013-09-14 02:17:...       None  both broad and n...             None
# 2009 2013-04-01 00:16:...       None  both broad and n...             None
# 2014 2009-03-25 23:31:...       None  both broad and n...             None
# 2067 2014-11-28 07:05:...       None  both broad and n...             None
# 2225 2011-09-04 00:07:...       None  both broad and n...             None
# 2228 2010-05-22 12:49:...       None  both broad and n...             None
# 2231 2012-07-13 12:22:...       None  both broad and n...             None
# 2261 2018-05-31 23:44:...       None  both broad and n...             None
# 2264 2018-06-04 21:55:...       None  both broad and n...             None
#
#      bw_from_hardware_model bw_from_transmit_frequency bandwidth  \
# 875                  None                   None            None
# 877                  None                   None            None
# 880                  None                   None            None
# 895                  None                   None            None
# 898                  None                   None            None
# 932                  None                   None            None
# 935                  None                   None            None
# 1030                 None                   None            None
# 1033                 None                   None            None
# 1036                 None                   None            None
# 1039                 None                   None            None
# 1080                 None                   None            None
# 1083                 None                   None            None
# 1086                 None                   None            None
# 1089                 None                   None            None
# 1092                 None                   None            None
# 1095                 None                   None            None
# 1098                 None                   None            None
# 1101                 None                   None            None
# 1105                 None                   None            None
# 1108                 None                   None            None
# 1111                 None                   None            None
# 1116                 None                   None            None
# 1119                 None                   None            None
# 1122                 None                   None            None
# 1125                 None                   None            None
# 1128                 None                   None            None
# 1131                 None                   None            None
# 1134                 None                   None            None
# 1190                 None                   None            None
# 1193                 None                   None            None
# 1195                 None                   None            None
# 1197                 None                   None            None
# 1199                 None                   None            None
# 1204                 None                   None            None
# 1207                 None                   None            None
# 1210                 None                   None            None
# 1213                 None                   None            None
# 1216                 None                   None            None
# 1219                 None                   None            None
# 1234                 None                   None            None
# 1256                 None                   None            None
# 1259                 None                   None            None
# 1262                 None                   None            None
# 1265                 None                   None            None
# 1268                 None                   None            None
# 1361                 None                   None            None
# 1374                 None                   None            None
# 1379                 None                   None            None
# 1382                 None                   None            None
# 1385                 None                   None            None
# 1388                 None                   None            None
# 1391                 None                   None            None
# 1394                 None                   None            None
# 1397                 None                   None            None
# 1400                 None                   None            None
# 1403                 None                   None            None
# 1406                 None                   None            None
# 1409                 None                   None            None
# 1412                 None                   None            None
# 1415                 None                   None            None
# 1418                 None                   None            None
# 1421                 None                   None            None
# 1426                 None                   None            None
# 1429                 None                   None            None
# 1435                 None                   None            None
# 1441                 None                   None            None
# 1444                 None                   None            None
# 1447                 None                   None            None
# 1469                 None                   None            None
# 1473                 None                   None            None
# 1476                 None                   None            None
# 1487                 None                   None            None
# 1518                 None                   None            None
# 1521                 None                   None            None
# 1545                 None                   None            None
# 1550                 None                   None            None
# 1553                 None                   None            None
# 1556                 None                   None            None
# 1559                 None                   None            None
# 1562                 None                   None            None
# 1565                 None                   None            None
# 1568                 None                   None            None
# 1571                 None                   None            None
# 1574                 None                   None            None
# 1577                 None                   None            None
# 1580                 None                   None            None
# 1604                 None                   None            None
# 1637                 None                   None            None
# 1653                 None                   None            None
# 1696                 None                   None            None
# 1699                 None                   None            None
# 1721                 None                   None            None
# 1729                 None                   None            None
# 1732                 None                   None            None
# 1735                 None                   None            None
# 1738                 None                   None            None
# 1741                 None                   None            None
# 1744                 None                   None            None
# 1747                 None                   None            None
# 1750                 None                   None            None
# 1753                 None                   None            None
# 1756                 None                   None            None
# 1759                 None                   None            None
# 1762                 None                   None            None
# 1765                 None                   None            None
# 1778                 None                   None            None
# 1781                 None                   None            None
# 1784                 None                   None            None
# 1787                 None                   None            None
# 1802                 None                   None            None
# 1804                 None                   None            None
# 1818                 None                   None            None
# 1822                 None                   None            None
# 1825                 None                   None            None
# 1828                 None                   None            None
# 1831                 None                   None            None
# 1834                 None                   None            None
# 1837                 None                   None            None
# 1840                 None                   None            None
# 1847                 None                   None            None
# 1852                 None                   None            None
# 1855                 None                   None            None
# 1858                 None                   None            None
# 1861                 None                   None            None
# 1864                 None                   None            None
# 1867                 None                   None            None
# 1870                 None                   None            None
# 1964                 None                   None            None
# 1967                 None                   None            None
# 1970                 None                   None            None
# 1973                 None                   None            None
# 1979                 None                   None            None
# 1985                 None                   None            None
# 1993                 None                   None            None
# 2009                 None                   None            None
# 2014                 None                   None            None
# 2067                 None                   None            None
# 2225                 None                   None            None
# 2228                 None                   None            None
# 2231                 None                   None            None
# 2261                 None                   None            None
# 2264                 None                   None            None
#
#                  comments
# 875   This is the ADCP...
# 877   This is the ADCP...
# 880   This is the ADCP...
# 895   This is the ADCP...
# 898   This is the ADCP...
# 932   This is the ADCP...
# 935   This is the ADCP...
# 1030  The transducer i...
# 1033  The transducer i...
# 1036  The transducer i...
# 1039  The transducer i...
# 1080  single-ping data...
# 1083  single-ping data...
# 1086  single-ping data...
# 1089  single-ping data...
# 1092  single-ping data...
# 1095  single-ping data...
# 1098  single-ping data...
# 1101  single-ping data...
# 1105  single-ping data...
# 1108  single-ping data...
# 1111  single-ping data...
# 1116  single-ping data...
# 1119  single-ping data...
# 1122  single-ping data...
# 1125  single-ping data...
# 1128  single-ping data...
# 1131  single-ping data...
# 1134  single-ping data...
# 1190  single-ping data...
# 1193  single-ping data...
# 1195  single-ping data...
# 1197  single-ping data...
# 1199  single-ping data...
# 1204  single-ping data...
# 1207  single-ping data...
# 1210  single-ping data...
# 1213  The Work Horse s...
# 1216  single-ping data...
# 1219  single-ping data...
# 1234  The well is///si...
# 1256  The transducer i...
# 1259  The transducer i...
# 1262  The transducer i...
# 1265  The transducer i...
# 1268  The transducer i...
# 1361  The transducer i...
# 1374  single-ping data...
# 1379  single-ping data...
# 1382  single-ping data...
# 1385  single-ping data...
# 1388  single-ping data...
# 1391  single-ping data...
# 1394  single-ping data...
# 1397  single-ping data...
# 1400  single-ping data...
# 1403  single-ping data...
# 1406  single-ping data...
# 1409  single-ping data...
# 1412  single-ping data...
# 1415  single-ping data...
# 1418  single-ping data...
# 1421  single-ping data...
# 1426  single-ping data...
# 1429  single-ping data...
# 1435  single-ping data...
# 1441  single-ping data...
# 1444  single-ping data...
# 1447  single-ping data...
# 1469  single-ping data...
# 1473  single-ping data...
# 1476  single-ping data...
# 1487  heading offset 4...
# 1518  single-ping data...
# 1521  single-ping data...
# 1545  heading offset 4...
# 1550  single-ping data...
# 1553  single-ping data...
# 1556  very shallow dep...
# 1559  single-ping data...
# 1562  single-ping data...
# 1565  single-ping data...
# 1568  single-ping data...
# 1571  single-ping data...
# 1574  single-ping data...
# 1577  single-ping data...
# 1580  single-ping data...
# 1604  The transducer i...
# 1637  single-ping data...
# 1653  The transducer i...
# 1696  The well is///si...
# 1699  The well is///si...
# 1721  heading offset 4...
# 1729  single-ping data...
# 1732  single-ping data...
# 1735  single-ping data...
# 1738  single-ping data...
# 1741  single-ping data...
# 1744  single-ping data...
# 1747  single-ping data...
# 1750  single-ping data...
# 1753  single-ping data...
# 1756  single-ping data...
# 1759  single-ping data...
# 1762  single-ping data...
# 1765  single-ping data...
# 1778  single-ping data...
# 1781  single-ping data...
# 1784  single-ping data...
# 1787  single-ping data...
# 1802  single-ping data...
# 1804  single-ping data...
# 1818  single-ping data...
# 1822  single-ping data...
# 1825  single-ping data...
# 1828  single-ping data...
# 1831  single-ping data...
# 1834  single-ping data...
# 1837  single-ping data...
# 1840  single-ping data...
# 1847  single-ping data...
# 1852  single-ping data...
# 1855  single-ping data...
# 1858  single-ping data...
# 1861  single-ping data...
# 1864  single-ping data...
# 1867  single-ping data...
# 1870  single-ping data...
# 1964  single-ping data...
# 1967  single-ping data...
# 1970  single-ping data...
# 1973  single-ping data...
# 1979  single-ping data...
# 1985  single-ping data...
# 1993  The transducer i...
# 2009  single-ping data...
# 2014  single-ping data...
# 2067  The transducer i...
# 2225  The well is///hd...
# 2228  hd_offset : 45.6...
# 2231  hd_offset: 28.15...
# 2261  was a Sentinel m...
# 2264  was a Sentinel m...

# %%
#pd.set_option('max_rows', 1000)
#pd.set_option('display.max_colwidth', -1)
#df.head()

# %% [markdown]
# ## Uniformly rename hardware_model names

# %%
# - Save out all unique hardware_model names + # of occurrences to look at in separate window
# --> use this output to create the legend below of how to translate different instrument names to a uniform list of names
#df['hardware_model'].value_counts().to_csv('jasadcp_unique_instruments.csv', header=['hardware_model count'])

# %% [markdown]
# #### **List of uniform instrument names:**
#
# **All names to become 'OS-38'**:\
# 'Ocean Surveyer 38', 'Ocean Surveyor 38'
#
# **All names to become 'OS-75'**:\
# 'Ocean Surveyor 75', 'OS75 narrowband', 'Ocean Surveyer 75', 'Ocean Surveyor 75 narrowband', 'OS75 (Ocean Surveyor)', 'Ocean Surveyor 75 broadband', 'Ocean Surveyor OS75', 'OS75', 'Ocean Surveryor 75', 'Ocean Surveyor 75 narroband', 'Ocean Surveyor 75 Broadband', 'Ocean Surveyor 75 Narrowband', '75KHz Ocean Surveyor narrowband', 'Ocean Surveyor 75 kHz', 'RDI 75KHz Ocean Surveyor', 'Ocean Surveyor 75 kHz Phased Array', '75KHz Ocean Surveyor'
#
# **All names to become 'OS-150'**:\
# 'Ocean Surveyer 150', 'Ocean Surveryor 150', 'Ocean Surveyor 150 narroband', 'Ocean Surveyor 150 narrowband', 'Ocean Surveyor 150 broadband'
#
# **All names to become 'OS-II-38'**:\
# 'Ocean Surveyor II (OS-II 38)'
#
# **All names to become 'OS-II-75'**:\
# 'OSII75S phased-array'
#
# **All names to become 'WH-300'**:\
# 'WorkHorse 300', 'Workhorse 300', 'Workhorse 300; 300 kHz'
#
# **All names to become 'WH-1200'**:\
# 'Workhorse 1200'
#
# **All names to become 'WH-Mariner-300'**:\
# 'Workhorse Mariner (300 kHz)'
#
# **All names to become 'WH-Mariner-600'**:\
# 'WorkHorse Mariner 600'
#
# **All names to become 'DCP4400A'**:\
# 'DCP4400A'
#
# **All names to become NB-VM-75:**\
# 'narrowband 75 kHz' (assume VM), 'VM75 narrowband'
#
# **All names to become NB-VM-150:**\
# 'Narrowband 150' (assume VM), 'NB 150' (assume VM), '150 narrowband' (assume VM), '150 kHz Narrowband' (assume VM), 'Vessel-mounted 150 kHz Narrowband' (HAS ALL SERIAL NUMBERS), 'Narrow Band 150Khz' (assume VM), 'Vessel-mount 150 kHz Narrowband', '1) Narrow Band 150 kHz' (assume VM), '150 kHz narrow band' (assume VM), 'Vessel-Mount 150 kHz Narrowband' (HAS ALL SERIAL NUMBERS), 'VM-150 Narrowband', 'RD-VM150 Narrow band', 'VM-150 (NB)', 'VM-150 narrowband', 'RDI VM150 narrowband', 'RD-VM150 narrowband', 'NB 150 (VM-150-18HP)' (assume 18HP makes no difference)
#
# **All names to become NB-VM-300:**\
# 'Narrowband 300' (assume VM), '300 narrow band' (assume VM)
#
# **All names to become NB-DR-150:**\
# 'Direct-Read 150 kHz Narrowband' (HAS ALL SERIAL NUMBERS)
#
# **All names to become BB-VM-150:**\
# 'Broadband 150' (assume VM),  'Broad Band 150' (assume VM), '150 kHz broadband' (assume VM), '"150 broad band, concave"' (assume VM)
#
# -----The following are mildly annoying:
# **All names to become 'VM-150'**:\
# 'VM-150', 'RD-VM150', 'VM150', 'RD-VM0150'
#
# **All names to become 'VM-300'**:\
# 'VM-300', 'RD-VM300'
#
# **All names to become 'UNCLEAR'**:\
# '150', 'RDI', '150 kHz hull mounted ADCP', 'Narrowband', '150 kHz', '153.6 kHz hull mounted ADCP'
#
# **Special cases**:\
# 1.) 'RD-VM' (HAS ALL SERIAL NUMBERS, READ TRANSMIT FREQUENCY, TOO - IF 150 THEN VM-150, ETC.)
# 2.) 'VM-150 and VM-300' (CHECKED NC FILES - CAN'T DTMN IF IT'S 150 OR 300 --> DISCARD)

# %%
# - Define fxn to uniformly rename different original hardware_model names
def set_uniform_name_orig_hardware_model(row):
    if row['hardware_model']:
        if row['hardware_model']=='DCP4400A':
            return 'DCP4400A'
        elif row['hardware_model'] in ['Ocean Surveyer 38', 'Ocean Surveyor 38']:
            return 'OS-38' 
        elif row['hardware_model'] in ['Ocean Surveyor 75', 'OS75 narrowband',
                                       'Ocean Surveyer 75', 'Ocean Surveyor 75 narrowband',
                                       'OS75 (Ocean Surveyor)', 'Ocean Surveyor 75 broadband',
                                       'Ocean Surveyor OS75', 'OS75', 'Ocean Surveryor 75',
                                       'Ocean Surveyor 75 narroband', 'Ocean Surveyor 75 Broadband',
                                       'Ocean Surveyor 75 Narrowband', '75KHz Ocean Surveyor narrowband',
                                       'Ocean Surveyor 75 kHz', 'RDI 75KHz Ocean Surveyor',
                                       'Ocean Surveyor 75 kHz Phased Array', '75KHz Ocean Surveyor']:
            return 'OS-75' 
        elif row['hardware_model'] in ['Ocean Surveyer 150', 'Ocean Surveryor 150',
                                       'Ocean Surveyor 150 narroband', 'Ocean Surveyor 150 narrowband',
                                       'Ocean Surveyor 150 broadband']:
            return 'OS-150'
        elif row['hardware_model'] in ['Ocean Surveyor II (OS-II 38)']:
            return 'OS-II-38'
        elif row['hardware_model'] in ['OSII75S phased-array']:
            return 'OS-II-75'
        elif row['hardware_model'] in ['VM75 narrowband']:
            return 'VM-75'
        elif row['hardware_model'] in ['VM-150', 'RD-VM150', 'VM-150 Narrowband', 'RD-VM150 Narrow band',
                                       'VM-150 (NB)', 'VM-150 narrowband', 'RDI VM150 narrowband',
                                       'VM150', 'RD-VM150 narrowband', 'RD-VM0150']:
            return 'VM-150'
        elif row['hardware_model'] in ['VM-300', 'RD-VM300']:
            return 'VM-300'
        elif row['hardware_model'] in ['RD-VM']:
            if re.search('150', row['transmit_frequency']):
                return 'VM-150'
        elif row['hardware_model'] in ['NB 150 (VM-150-18HP)']:
            return 'VM-150-18HP'
        elif row['hardware_model'] in ['WorkHorse 300', 'Workhorse 300', 'Workhorse 300; 300 kHz']:
            return 'Workhorse-300'
        elif row['hardware_model'] in ['Workhorse 1200']:
            return 'Workhorse-1200'
        elif row['hardware_model'] in ['Workhorse Mariner (300 kHz)']:
            return 'Workhorse-Mariner-300'
        elif row['hardware_model'] in ['WorkHorse Mariner 600']:
            return 'Workhorse-Mariner-600'
        else:
            return 'ZUNCLEAR: ' + row['hardware_model']
    else:
        return None

# %%
# - Create df w/ uniform instrument names
df['instrument_name']=df.apply(set_uniform_name_orig_hardware_model, axis=1)
cols = list(df.columns.values)
cols = cols[0:2]+['instrument_name']+cols[2:-1]
df = df[cols]

# %%
# - Get rid of NULL instrument_name rows (there's only 1 and it has no other info)
# and 'ZUNCLEAR: VM-150 and VM-300' rows
df = df[~df['instrument_name'].isnull()]
df = df[~(df['instrument_name']=='ZUNCLEAR: VM-150 and VM-300')]

# %%
# - Get rid of columns not needed anymore
df.drop(columns=['bw_from_comments','bw_from_hardware_model',
                 'bw_from_transmit_frequency'], inplace=True)

# %%
# pacific only
#01285 - 1st HOTS w/ NB150 in 2005!!
#01287
#01289
#01291
#01527
#01528
#02131
#02133
#02135
#02137
#
# southern ocean
#02111
#
#00803
#00805

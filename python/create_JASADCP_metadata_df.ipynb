# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
import xarray as xr

# %%
# - Set data path
dpath = '/opt/acoustic-variability/data/'

# %%
# - Set saved out figure path
figpath = '/opt/acoustic-variability/python/figures/'

# %% [markdown]
# # Compile JASADCP metadata

# %% [markdown]
# ## Read JASADCP metadata into df

# %%
fnames = sorted(os.listdir(dpath + 'JASADCP/ncfiles'))

# %%
nc_counter = len(fnames)
hardware_model = [None]*nc_counter
serial_numbers = [None]*nc_counter
transmit_frequency = [None]*nc_counter
phased_array = [None]*nc_counter
cruise_beg_date = [None]*nc_counter
blanking_interval = [None]*nc_counter
bin_length = [None]*nc_counter
transducer_beam_angle = [None]*nc_counter
transmit_pulse_length = [None]*nc_counter
comments = [None]*nc_counter
biomass_dtmn = [None]*nc_counter
geo_region = [None]*nc_counter
chief_scientist = [None]*nc_counter
personnel_charge = [None]*nc_counter
manufacturer = [None]*nc_counter
transducer_config = [None]*nc_counter
depth_range = [None]*nc_counter
num_bins = [None]*nc_counter
ens_avg_intvl = [None]*nc_counter
ss_calc = [None]*nc_counter
project = [None]*nc_counter
nb150 = [None]*nc_counter
nb300 = [None]*nc_counter
bb150 = [None]*nc_counter
bb300 = [None]*nc_counter
beam_width = [None]*nc_counter
all_text = [None]*nc_counter

# %%
ifile = 0
for fname in fnames:
    ncfile = dpath + 'JASADCP/ncfiles/' + fname
    ncnow = xr.open_dataset(ncfile)
    strnow = ncnow.attrs['cruise_sonar_summary']
    # 1.) hardware_model
    hardware_modelnow = re.findall("HARDWARE MODEL *: *((?:\S+ )*\S+)", strnow)
    if hardware_modelnow:
        hardware_model[ifile] = hardware_modelnow[0]
    elif not hardware_modelnow: # if hardware_modelnow is empty
        manufacturernow = re.findall("MANUFACTURER *: *((?:\S+ )*\S+)", strnow)
        if manufacturernow:
            hardware_model[ifile] = manufacturernow[0]
    # 2.) serial_numbers
    serial_numbersnow = re.findall("SERIAL NUMBERS *: *((?:\S+ )*\S+)", strnow)
    if serial_numbersnow:
        serial_numbers[ifile] = serial_numbersnow[0]
    # 3.) transmit_frequency
    transmit_frequencynow = re.findall("TRANSMIT FREQUENCY *: *((?:\S+ )*\S+)", strnow)
    if transmit_frequencynow:
        transmit_frequency[ifile] = transmit_frequencynow[0]
    # 4.) phased_array 
    phased_arraynow = re.findall("phased.array", strnow, re.IGNORECASE)
    if phased_arraynow:
        sep = '///'; phased_arraynow = sep.join(phased_arraynow)
        phased_array[ifile] = phased_arraynow
    # 5.) cruise_beg_date
    cruise_beg_date[ifile] = ncnow['time'][0].values
    # 6.) blanking_interval
    blanking_intervalnow = re.findall("BLANKING INTERVAL *: *((?:\S+ )*\S+)", strnow)
    if blanking_intervalnow:
        blanking_interval[ifile] = blanking_intervalnow[0]
    # 7.) bin_length
    bin_lengthnow = re.findall("BIN LENGTH *: *((?:\S+ )*\S+)", strnow)
    if bin_lengthnow:
        bin_length[ifile] = bin_lengthnow[0]
    # 8.) transducer_beam_angle
    transducer_beam_anglenow = re.findall("TRANSDUCER BEAM ANGLE *: *((?:\S+ )*\S+)", strnow)
    if transducer_beam_anglenow:
        transducer_beam_angle[ifile] = transducer_beam_anglenow[0]
    # 9.) transmit_pulse_length
    transmit_pulse_lengthnow = re.findall("TRANSMIT PULSE LENGTH *: *((?:\S+ )*\S+)", strnow)
    if transmit_pulse_lengthnow:
        transmit_pulse_length[ifile] = transmit_pulse_lengthnow[0]
    # 10.) comments
    commentsnow = re.findall("COMMENTS *: *((?:\S+ )*\S+)", strnow)
    if commentsnow:
        sep = '///'; commentsnow = sep.join(commentsnow)
        comments[ifile] = commentsnow
    # 11.) biomass_dtmn
    biomass_dtmnnow = re.findall("BIOMASS DETERMINATION *: *((?:\S+ )*\S+)", strnow)
    if biomass_dtmnnow:
        biomass_dtmn[ifile] = biomass_dtmnnow[0]
    # 12.) geo_region
    geo_regionnow = re.findall("GEOGRAPHIC_REGION *: *((?:\S+ )*\S+)", strnow)
    if geo_regionnow:
        geo_region[ifile] = geo_regionnow[0]
    # 13.) chief_scientist
    chief_scientistnow = re.findall("CHIEF SCIENTIST ON SHIP *: *((?:\S+ )*\S+)", strnow)
    if chief_scientistnow:
        chief_scientist[ifile] = chief_scientistnow[0]
    # 14.) personnel_charge
    personnel_chargenow = re.findall("PERSONNEL IN CHARGE *: *((?:\S+ )*\S+)", strnow)
    if personnel_chargenow:
        personnel_charge[ifile] = personnel_chargenow[0]
    # 15.) manufacturer
    manufacturernow = re.findall("MANUFACTURER *: *((?:\S+ )*\S+)", strnow)
    if manufacturernow:
        manufacturer[ifile] = manufacturernow[0]
    # 16.) transducer_config
    transducer_confignow = re.findall("TRANSDUCER CONFIGURATION *: *((?:\S+ )*\S+)", strnow)
    if transducer_confignow:
        transducer_config[ifile] = transducer_confignow[0]
    # 17.) depth_range
    depth_rangenow = re.findall("DEPTH RANGE *: *((?:\S+ )*\S+)", strnow)
    if depth_rangenow:
        depth_range[ifile] = depth_rangenow[0]
    # 18.) num_bins
    num_binsnow = re.findall("NUMBER OF BINS *: *((?:\S+ )*\S+)", strnow)
    if num_binsnow:
        num_bins[ifile] = num_binsnow[0]
    # 19.) ens_avg_intvl
    ens_avg_intvlnow = re.findall("ENSEMBLE AVERAGING INTERVAL *: *((?:\S+ )*\S+)", strnow)
    if ens_avg_intvlnow:
        ens_avg_intvl[ifile] = ens_avg_intvlnow[0]
    # 20.) ss_calc
    ss_calcnow = re.findall("SOUND SPEED CALCULATION *: *((?:\S+ )*\S+)", strnow)
    if ss_calcnow:
        ss_calc[ifile] = ss_calcnow[0]
    # 21.) project
    projectnow = re.findall("PROJECT *: *((?:\S+ )*\S+)", strnow)
    if projectnow:
        project[ifile] = projectnow[0]
    # 22.) nb150
    nb150now = re.findall("nb150", strnow, re.IGNORECASE)
    if nb150now:
        sep = '///'; nb150now = sep.join(nb150now)
        nb150[ifile] = nb150now
    # 23.) nb300
    nb300now = re.findall("nb300", strnow, re.IGNORECASE)
    if nb300now:
        sep = '///'; nb300now = sep.join(nb300now)
        nb300[ifile] = nb300now
    # 22.) bb150
    bb150now = re.findall("bb150", strnow, re.IGNORECASE)
    if bb150now:
        sep = '///'; bb150now = sep.join(bb150now)
        bb150[ifile] = bb150now
    # 23.) bb300
    bb300now = re.findall("bb300", strnow, re.IGNORECASE)
    if bb300now:
        sep = '///'; bb300now = sep.join(bb300now)
        bb300[ifile] = bb300now
    # 24.) beam_width
    beam_widthnow = re.findall("ACOUSTIC BEAM WIDTH *: *((?:\S+ )*\S+)", strnow)
    if beam_widthnow:
        beam_width[ifile] = beam_widthnow[0]
    # 25.) all_text
    all_text[ifile] = strnow
    ifile = ifile+1

# %%
df = pd.concat([pd.Series(fnames,name='fname'),
     pd.Series(hardware_model,name='hardware_model'),pd.Series(serial_numbers,name='serial_numbers'),
     pd.Series(transmit_frequency,name='transmit_frequency'),pd.Series(phased_array,name='phased_array'),
     pd.Series(cruise_beg_date,name='cruise_beg_date'),pd.Series(blanking_interval,name='blanking_interval'),
     pd.Series(bin_length,name='bin_length'),pd.Series(transducer_beam_angle,name='transducer_beam_angle'),
     pd.Series(transmit_pulse_length,name='transmit_pulse_length'),pd.Series(comments,name='comments'),
     pd.Series(biomass_dtmn,name='biomass_dtmn'),pd.Series(geo_region,name='geo_region'),
     pd.Series(chief_scientist,name='chief_scientist'),pd.Series(personnel_charge,name='personnel_charge'),
     pd.Series(manufacturer,name='manufacturer'),pd.Series(transducer_config,name='transducer_config'),
     pd.Series(depth_range,name='depth_range'),pd.Series(num_bins,name='num_bins'),
     pd.Series(ens_avg_intvl,name='ens_avg_intvl'),pd.Series(ss_calc,name='ss_calc'),
     pd.Series(project,name='project'),pd.Series(nb150,name='nb150'),
     pd.Series(nb300,name='nb300'),pd.Series(bb150,name='bb150'),
     pd.Series(bb300,name='bb300'),pd.Series(beam_width,name='beam_width'),
     pd.Series(all_text,name='all_text')],
    axis=1)

# %%
# - Define fxns to describe bandwidth from comments, hardware_model, and transmit_frequency 

# --> Checks for hardware_model names containing NB = narrowband
#dfnow = df.dropna(subset=['hardware_model'])
#dfnow[dfnow['hardware_model'].str.contains('NB')]['hardware_model'].unique()
# --> Results are:
# array(['NB 150 (VM-150-18HP)', 'NB 150', 'VM-150 (NB)'], dtype=object)

def set_bandwidth_from_all_text(row):
# I use "broadband" instead of "broad" here b/c we have some cruise comments that say "broad-scale"
    if row['all_text']:
        if   ( (re.search('broadband', row['all_text'], re.IGNORECASE) or
                re.search('broad band', row['all_text'], re.IGNORECASE))
                and
               (re.search('narro', row['all_text'], re.IGNORECASE) or
                re.search('nb75', row['all_text'], re.IGNORECASE) or
                re.search('nb150', row['all_text'], re.IGNORECASE) or
                re.search('nb300', row['all_text'], re.IGNORECASE) or
                re.search('nb600', row['all_text'], re.IGNORECASE) or
                re.search('nb1200', row['all_text'], re.IGNORECASE))
             ):
            return 'both broad and narrowband?' 
        elif (re.search('broadband', row['all_text'], re.IGNORECASE) or
              re.search('broad band', row['all_text'], re.IGNORECASE)
             ):
            return 'broadband'
        elif (re.search('narro', row['all_text'], re.IGNORECASE) or
              re.search('nb75', row['all_text'], re.IGNORECASE) or
              re.search('nb150', row['all_text'], re.IGNORECASE) or
              re.search('nb300', row['all_text'], re.IGNORECASE) or
              re.search('nb600', row['all_text'], re.IGNORECASE) or
              re.search('nb1200', row['all_text'], re.IGNORECASE)
             ):
            return 'narrowband'
        else:
            return None
    else:
        return None

def set_bandwidth_from_comments(row):
# I use "broadband" instead of "broad" here b/c we have some cruise comments that say "broad-scale"
    if row['comments']:
        if (re.search('broadband', row['comments'], re.IGNORECASE) and
                re.search('narro', row['comments'], re.IGNORECASE)):
            return 'both broad and narrowband?' 
        elif re.search('broadband', row['comments'], re.IGNORECASE):
            return 'broadband'
        elif re.search('narro', row['comments'], re.IGNORECASE):
            return 'narrowband'
        else:
            return None
    else:
        return None
    
def set_bandwidth_from_hardware_model(row):
    if row['hardware_model']:
        if re.search('broad', row['hardware_model'], re.IGNORECASE):
            return 'broadband'
        elif (re.search('narro', row['hardware_model'], re.IGNORECASE) or
                re.search('nb', row['hardware_model'], re.IGNORECASE)):
            return 'narrowband'
        else:
            return None
    else:
        return None

def set_bandwidth_from_transmit_frequency(row):
    if row['transmit_frequency']:
        if re.search('broadband', row['transmit_frequency'], re.IGNORECASE):
            return 'broadband'
        elif re.search('narro', row['transmit_frequency'], re.IGNORECASE):
            return 'narrowband'
        else:
            return None
    else:
        return None
    
def set_final_bandwidth(row):
    lsnow = [row['bw_from_comments'],row['bw_from_hardware_model'],row['bw_from_transmit_frequency']]
    idxnow = [i for i,lsitem in enumerate(lsnow) if lsitem != None]
    if len(idxnow)>0:
        if len(idxnow)==3:
            if lsnow[1]!=lsnow[2]:
                return 'CHECK NC FILE'
            else:
                return lsnow[2]
        elif len(idxnow)==2:
            if idxnow==[0,1]:
            # prioritize bw_from_hardware_model over bw_from_comments
                return lsnow[1]
            elif idxnow==[0,2]:
            # prioritize bw_from_transmit_frequency over bw_from_comments
                return lsnow[2]
            elif (idxnow==[1,2]) and (lsnow[1]==lsnow[2]):
                return lsnow[2]
            elif (idxnow==[1,2]) and (lsnow[1]!=lsnow[2]):
            # equal priority for bw_from_transmit_frequency and bw_from_hardware_model
                return 'CHECK NC FILE'            
        elif len(idxnow)==1:
            return lsnow[idxnow[0]]
    else:
        return None

# %%
df['bw_from_all_text']=df.apply(set_bandwidth_from_all_text, axis=1)
df['bw_from_comments']=df.apply(set_bandwidth_from_comments, axis=1)
df['bw_from_hardware_model']=df.apply(set_bandwidth_from_hardware_model, axis=1)
df['bw_from_transmit_frequency']=df.apply(set_bandwidth_from_transmit_frequency, axis=1)
df['bandwidth']=df.apply(set_final_bandwidth, axis=1)
# - Testing (old as of 1/28/20)
#pd.set_option('max_rows', 500)
#pd.set_option('display.max_colwidth', -1)
#df[df['bw_from_comments']=='narrowband'][['hardware_model','transmit_frequency','bw_from_comments','bw_from_hardware_model','bw_from_transmit_frequency','bandwidth','comments']]
# also looked at: ['bw_from_comments']=='broadband', ['bw_from_hardware_model']=='narrowband',
# ['bw_from_hardware_model']=='broadband', ['bw_from_transmit_frequency']=='narrowband',
# ['bw_from_hardware_model']=='broadband', ['bandwidth']=='CHECK NC FILE'
# --> I CHECKED ALL PRINTED OUT ROWS AND ALL GOT THE RIGHT ANSWER IN THE 
# FINAL COLUMN NAMED 'bandwidth'; ALSO no files triggered the 'CHECK NC FILE'
# designation in the 'bandwidth' column, yay!

# %%
# - See if looking for nb150, nb300, bb300, bb150 helps w/ figuring out NB vs. BB
# --> Seems like looking for "nb150" may help

#df[(df['nb150'].notnull()) & ~(df['bandwidth'].notnull())
#  ][['hardware_model','nb150','nb300','bb150','bb300','bw_from_all_text','bandwidth']]
# --> lots of them

#df[(df['nb300'].notnull()) & ~(df['bandwidth'].notnull())
#  ][['hardware_model','nb150','nb300','bb150','bb300','bw_from_all_text','bandwidth']]
# --> none

#df[(df['bb300'].notnull()) & ~(df['bandwidth'].notnull())
#  ][['hardware_model','nb150','nb300','bb150','bb300','bw_from_all_text','bandwidth']]
# --> none

#df[(df['bb150'].notnull()) & ~(df['bandwidth'].notnull())
#  ][['hardware_model','nb150','nb300','bb150','bb300','bw_from_all_text','bandwidth']]
# --> none

# %%
#pd.set_option('display.max_colwidth', 200)

# - What does beam_width tell us?
#print(df[df['beam_width'].notnull()]['beam_width'].unique())
#df[df['beam_width'].notnull()][['fname','beam_width','bandwidth']]
# --> "unconfirmed (narrow band)" tells us NB! that's it though 

# - What does "30 degrees" tell us?
#print(len(df[df['beam_width']=='30 degrees']))
#df[df['beam_width']=='30 degrees'].drop('all_text', axis=1)
#df[df['beam_width']=='30 degrees'][['fname','comments','bandwidth']]
# --> discovered an error in these files;
# --> 30 degrees should most prob be under TRANSDUCER BEAM ANGLE, NOT ACOUSIT BEAM WIDTH

# %% [markdown]
# ### Updates that HAVE to be manual
# - 01258_short.nc is narrowband from checking ncfile (currently "both broad and narrowband?")
# --> need to search for "os38nb" in CRUISE_NAME

# %%
# - Tracking results from cell below:
# ***** = first mention of this technique

# ---- broadband from all_text
#--> the 1 file came up b/c of "broadband seismograph"
#--> not real :(

# ---- narrowband from all_text
#--> 174 total
#--> 00014_short.nc not narrowband, just had the phrase narrow time period
#    ...*****require "narrowband" or "narrow band" in all_text
#--> 00090-00095_short not narrowband, just had some place Narrows 
#    ...require "narrowband" or "narrow band" in all_text
#--> 00111-00117_short IS narrowband, VM150, "narrow band" from ACOUSTIC BEAM WIDTH so added beam_width.notnull()
#    ...the above is not in this set anymore then (now will be <174 total)
#    ...*****add beam_width as criteria w/ priority above comments and all_text (only matters for 00111-00117_short.nc)
#--> 00544-00545_short not narrowband, narrow channel/narrowly-spaced
#    ...require "narrowband" or "narrow band" in all_text
#--> 00803,5_short IS narrowband, NB150 in next-line comments, nb150 from CRUISE_NAME
#    ...*****use CRUISE_NAME looking for "nb150"
#--> 00900-00923_short not narrowband, just had some place Narrows and maybe other phrases
#    ...require "narrowband" or "narrow band" in all_text
#--> 01285,7,9_short IS narrowband, NB150 in next-line comments, nb150 from CRUISE_NAME
#    ...use CRUISE_NAME looking for "nb150"
#--> 01340-01435(skipping every other ish)_short IS narrowband, NB150 in next-line comments, nb150 from CRUISE_NAME
#    ...use CRUISE_NAME looking for "nb150"
#--> 01527-8_short IS narrowband, nb150 from CRUISE_NAME
#    ...use CRUISE_NAME looking for "nb150"
#--> 01567_short IS narrowband, nb150 from CRUISE_NAME
#    ...use CRUISE_NAME looking for "nb150"
#--> 01574-01760(skipping every other ish)_short IS narrowband, nb150 from CRUISE_NAME, NB150 in next-line comments and ATTACHMENT TO THE HULL
#    ...use CRUISE_NAME looking for "nb150"
#--> 01814-6_short IS narrowband, "narrowband mode" from COMMENT (no S! UGH)
#    ...*****use COMMENT like COMMENTS looking for "narrowband"
#--> 01987-02159(skipping every other ish)_short IS narrowband, nb150 from CRUISE_NAME, NB150 in next-line comments and ATTACHMENT TO THE HULL
#    ...use CRUISE_NAME looking for "nb150"
#--> 02161_short IS narrowband, "75 kHz narrowband" from COMMENT (no S! UGH) 
#    ...use COMMENT like COMMENTS looking for "narrowband"
#--> 02172-02253(skipping every other ish)_short IS narrowband, nb150 from CRUISE_NAME, NB150 in next-line comments and ATTACHMENT TO THE HULL
#    ...use CRUISE_NAME looking for "nb150"
#--> 02355-68_short not narrowband, just had some place Narrows 
#    ...require "narrowband" or "narrow band" in all_text

# ---- both broad and narrowband? from all_text
# --> 143 total
#--> 00925 = implies broadband?? or maybe there was only one bandwidth avail then? HOT, WH300, 2005
#    ..."Broadband gives greater resolution but less depth penetration and narrowband visa versa. The Workhorse 300 allows the highest resolution."
#    ...also b/c it says "ADCP data from the RDI OS38 Broadband are found in SAC ID 00924."
#--> 00927 = narrowband?? or maybe there was only one bandwidth avail then? HOT, WH300, 2005
#    ...b/c it says "ADCP data from the RDI OS38 narrowband are found in SAC ID 00926."
#    ...but also says the same 1st quote as above
#--> 00930 = broadband?? HOT, WH300, 2005
#    ...it says "ADCP data from the RDI OS38 broadband (SAC ID 00928) and narrowband (SAC ID 00929) are also available for this cruise."
#    ...but also says the same 1st quote as above
#--> 00945 = broadband?? WH300, 2005
#    ...it says "Narrowband mode (SAC ID 00944) and the broadband (SAC 00943) mode are inter-leaved from the OS38 instrument.  This cruise also includes ADCP data from the Workhorse 300, which is in SAC ID 00945."
#    ...but also says the same 1st quote as above
#--> 00948 = broadband?? same as above
#--> 00982 = broadband?? same as above
#--> 00985 = broadband?? same as above
#--> 01087-96(skipping every other ish) = narrowband, nb150 from CRUISE_NAME, NB150 in next-line comments and ATTACHMENT TO THE HULL
#    ...use CRUISE_NAME looking for "nb150"
#--> 01137-68(skipping every other ish) = broadband?? HOT, WH300, 2006
#--> 01173-91(skipping every other ish) = broadband?? HOT, WH300, 2007
#--> 01247 = broadband?? not HOT, but same as all above, WH300, 2005
#--> 01250-61(skipping every other ish) = broadband?? HOT, WH300, 2005
#--> 01264 = broadband?? not HOT but in Pac, same as all above, WH300, 2006
#--> 01267-70 = broadband?? not HOT but in Pac, same as all above, WH300, 2007
#--> 01273-6 = broadband?? not HOT but in Pac, same as all above, WH300, 2008
#--> 01291 = narrowband
#    ...use CRUISE_NAME looking for "nb150"
#--> 01325-01430(skipping every other ish) = narrowband, nb150 from CRUISE_NAME, NB150 in next-line comments and ATTACHMENT TO THE HULL
#    ...use CRUISE_NAME looking for "nb150"
#--> 01447 = broadband! NPSG, WH300, 2008, "This cruise has two instruments, 38kHz phased array ("Ocean Surveyor") capable of pinging in broadband or narrowband (or interleaved) modes, and a 300kHz broadband "Workhorse" ADCP." in comments. "The Workhorse 300 has the highest time- and depth- resolution, but rarely reaches deeper than 80m." in comments.
#    ...*****needs manual specification! Or searching for "300kHz "Workhorse" ADCP"
#--> 01452-01664,01721,01780-02098,02122,02348(skipping every other ish) = broadband! same as above, HOT and others, WH300, 2008-14
#    ...needs manual specification! Or searching for "300kHz "Workhorse" ADCP"
#--> 01688,01737,02106,02180 = narrowband, nb150 from CRUISE_NAME, NB150 in next-line comments and ATTACHMENT TO THE HULL
#    ...use CRUISE_NAME looking for "nb150"
#--> 02127 = narrowband! "These datasets NB150 and OS75 narrowband have NODC SAC IDs 02126 and 02127, respectively."
#    ...use COMMENT like COMMENTS looking for "narrowband"
#    ...*****OR use CRUISE_NAME looking for "os75nb"
#--> 02384,7 = broadband! WH300, 2018, 1 comment said: "was a Sentinel model?" lol
#    ...*****search for "pingtype = bb" in all_text
#--> BASICALLY, IN SUM, ALL WH300 WITH "both broad and narrowband?" STATUS IN bw_from_all_text CAN BE ASSUMED/FILLED INTO BE BROADBAND

# %%
pd.set_option('max_rows', 2200)
#pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_colwidth', 20)
#dfnow = df[(df['bw_from_all_text']=='broadband') &
dfnow = df[~(df['bw_from_all_text'].notnull()) &
           ~(df['bw_from_hardware_model'].notnull()) &
           ~(df['bw_from_transmit_frequency'].notnull()) &
           ~(df['bw_from_comments'].notnull())
           #~(df['beam_width'].notnull()) #&
           #(df.index>2261)
  ][['hardware_model','transmit_frequency','fname','cruise_beg_date','beam_width',
     'bw_from_all_text','bw_from_comments','bw_from_hardware_model',
     'bw_from_transmit_frequency','bandwidth','comments']]
print(len(dfnow))
dfnow
# Out:
# 703
#            hardware_model   transmit_frequency           fname  \
# 0                RD-VM150       150 kHz except  00001_short.nc
# 1                RD-VM150                 None  00002_short.nc
# 2                RD-VM150                 None  00003_short.nc
# 3                RD-VM150              153 kHz  00004_short.nc
# 4               RD-VM0150              153 kHz  00005_short.nc
# 5                RD-VM150              153 kHz  00006_short.nc
# 6                RD-VM150              153 kHz  00007_short.nc
# 7                RD-VM150              153 kHz  00008_short.nc
# 8                RD-VM150              153 kHz  00009_short.nc
# 9                RD-VM150              153 kHz  00010_short.nc
# 10               RD-VM150              153 kHz  00011_short.nc
# 11               RD-VM150              153 kHz  00012_short.nc
# 12               RD-VM150              153 kHz  00013_short.nc
# 14                    RDI                 None  00015_short.nc
# 15               RD-VM150              153 kHz  00016_short.nc
# 16               RD-VM150              153 kHz  00017_short.nc
# 17               RD-VM150              153 kHz  00018_short.nc
# 18               RD-VM150              153 kHz  00019_short.nc
# 19               RD-VM150              153 kHz  00020_short.nc
# 20               RD-VM150              153 kHz  00021_short.nc
# 21                    RDI              153 KHz  00022_short.nc
# 22                    RDI              153 KHz  00023_short.nc
# 23                    RDI              153 KHz  00024_short.nc
# 24                    RDI              153 KHz  00025_short.nc
# 25               RD-VM150              153 kHz  00026_short.nc
# 26               RD-VM150              153 kHz  00027_short.nc
# 27               RD-VM150              153 kHz  00028_short.nc
# 28               RD-VM150              153 kHz  00029_short.nc
# 29               RD-VM150              153 kHz  00030_short.nc
# 30               RD-VM150              153 kHz  00031_short.nc
# 31               RD-VM150              153 kHz  00032_short.nc
# 32               RD-VM150              153 kHz  00033_short.nc
# 33               RD-VM150              153 kHz  00034_short.nc
# 34               RD-VM150              153 kHz  00035_short.nc
# 35               RD-VM150              153 kHz  00036_short.nc
# 36               RD-VM150              153 kHz  00037_short.nc
# 37               DCP4400A  115 kHz along 3 ...  00038_short.nc
# 38                 VM-150              153 KHz  00039_short.nc
# 39                 VM-150              153 KHz  00040_short.nc
# 40                 VM-150              153 KHz  00041_short.nc
# 41                 VM-150              153 KHz  00042_short.nc
# 42                 VM-150              153 KHz  00043_short.nc
# 43                 VM-150              153 KHz  00044_short.nc
# 44                 VM-150              153 KHz  00045_short.nc
# 45                 VM-150              153 KHz  00046_short.nc
# 46                 VM-150              153 KHz  00047_short.nc
# 47                 VM-150              153 KHz  00048_short.nc
# 48                 VM-150              153 KHz  00049_short.nc
# 49                 VM-150              153 KHz  00050_short.nc
# 50                 VM-300              306 KHz  00051_short.nc
# 51                 VM-300              306 KHz  00052_short.nc
# 52                 VM-300              306 KHz  00053_short.nc
# 53                 VM-300              306 KHz  00054_short.nc
# 54                 VM-300              306 KHz  00055_short.nc
# 55                 VM-300              306 KHz  00056_short.nc
# 56                 VM-150              153 KHz  00057_short.nc
# 57                 VM-150              153 KHz  00058_short.nc
# 58                 VM-150              153 KHz  00059_short.nc
# 59                 VM-150              153 KHz  00060_short.nc
# 60                 VM-150              153 KHz  00061_short.nc
# 61                 VM-150              153 KHz  00062_short.nc
# 62                 VM-150              153 KHz  00063_short.nc
# 63                 VM-150              153 KHz  00064_short.nc
# 64                 VM-150              153 KHz  00065_short.nc
# 65                 VM-150              153 KHz  00066_short.nc
# 66                 VM-150              153 KHz  00067_short.nc
# 67                 VM-150              153 KHz  00068_short.nc
# 68                 VM-150              153 KHz  00069_short.nc
# 69                 VM-150              153 KHz  00070_short.nc
# 70                 VM-150              153 KHz  00071_short.nc
# 71                 VM-150              153 KHz  00072_short.nc
# 72                 VM-150              153 KHz  00073_short.nc
# 73                 VM-150              153 KHz  00074_short.nc
# 74                 VM-150              153 KHz  00075_short.nc
# 75                 VM-150              153 KHz  00076_short.nc
# 76                 VM-150              153 KHz  00077_short.nc
# 79                 VM-150              153 KHz  00080_short.nc
# 80                 VM-150              153 KHz  00081_short.nc
# 81                 VM-150              153 KHz  00082_short.nc
# 82               RD-VM150              153 kHz  00083_short.nc
# 83               RD-VM150              153 kHz  00084_short.nc
# 84               RD-VM150              153 kHz  00085_short.nc
# 85               RD-VM150              153 kHz  00086_short.nc
# 86               RD-VM300            306.8 kHz  00087_short.nc
# 87               RD-VM300            306.8 kHz  00088_short.nc
# 88               RD-VM300            306.8 kHz  00089_short.nc
# 94                 VM-150              153 KHz  00096_short.nc
# 95                 VM-150              153 KHz  00097_short.nc
# 96                 VM-150              153 KHz  00098_short.nc
# 97                 VM-150              153 KHz  00099_short.nc
# 98                 VM-150              153 KHz  00100_short.nc
# 99                 VM-150              153 KHz  00101_short.nc
# 100                VM-150              153 KHz  00102_short.nc
# 101                VM-150              153 KHz  00103_short.nc
# 102                VM-150              153 KHz  00104_short.nc
# 103                VM-150              153 KHz  00105_short.nc
# 104                VM-150              153 KHz  00106_short.nc
# 105              RD-VM150              153 kHz  00107_short.nc
# 106              RD-VM150              153 kHz  00108_short.nc
# 107              RD-VM150              153 kHz  00109_short.nc
# 108              RD-VM150              153 kHz  00110_short.nc
# 116              RD-VM150              153 kHz  00118_short.nc
# 117              RD-VM150              153 kHz  00119_short.nc
# 118                VM-150              153 KHz  00120_short.nc
# 119                VM-150              153 KHz  00121_short.nc
# 122                VM-150                 None  00124_short.nc
# 123              RD-VM150                 None  00125_short.nc
# 124              RD-VM300            306.8 kHz  00126_short.nc
# 125              RD-VM300            306.8 kHz  00127_short.nc
# 126              RD-VM300            306.8 kHz  00128_short.nc
# 127              RD-VM150                 None  00129_short.nc
# 128              RD-VM150                 None  00130_short.nc
# 129                VM-150                 None  00134_short.nc
# 130                VM-150                 None  00135_short.nc
# 131                VM-150              153 KHz  00136_short.nc
# 132                VM-150              153 KHz  00137_short.nc
# 133              RD-VM150              153 kHz  00138_short.nc
# 134                VM-150              153 KHz  00139_short.nc
# 135                VM-150              153 KHz  00140_short.nc
# 136                VM-150              153 KHz  00141_short.nc
# 137                VM-150              153 KHz  00142_short.nc
# 138                VM-150              153 KHz  00143_short.nc
# 139                VM-150                 None  00144_short.nc
# 140               150 kHz                 None  00145_short.nc
# 141               150 kHz                 None  00146_short.nc
# 142                VM-150                 None  00147_short.nc
# 143                VM-150                 None  00148_short.nc
# 144                VM-150                 None  00149_short.nc
# 145                VM-150                 None  00150_short.nc
# 146               150 kHz                 None  00151_short.nc
# 147                VM-150              153 KHz  00152_short.nc
# 148                VM-150              153 KHz  00153_short.nc
# 149                VM-150              153 KHz  00154_short.nc
# 150                VM-150              153 KHz  00155_short.nc
# 151                   RDI              153 KHz  00156_short.nc
# 152              RD-VM150              150 KHz  00157_short.nc
# 153                VM-150                 None  00158_short.nc
# 154                VM-150                 None  00159_short.nc
# 155                VM-150                 None  00160_short.nc
# 156                VM-150                 None  00161_short.nc
# 157                VM-150              153 KHz  00162_short.nc
# 158              RD-VM150              153 kHz  00163_short.nc
# 159                VM-150              153 KHz  00164_short.nc
# 161                   RDI              153 KHz  00166_short.nc
# 162                   RDI              153 KHz  00167_short.nc
# 163              RD-VM150              153 kHz  00168_short.nc
# 164                VM-150              153 KHz  00171_short.nc
# 165                VM-150              153 KHz  00172_short.nc
# 166                VM-150                 None  00173_short.nc
# 167                VM-150                 None  00174_short.nc
# 169                VM-150                 None  00176_short.nc
# 179                VM-150                 None  00186_short.nc
# 180                VM-150                 None  00187_short.nc
# 181                VM-150                 None  00188_short.nc
# 182                VM-150                 None  00189_short.nc
# 183                VM-150                 None  00190_short.nc
# 184                VM-150                 None  00191_short.nc
# 185                VM-150              153 KHz  00192_short.nc
# 186                VM-150              153 KHz  00193_short.nc
# 187                VM-150              153 KHz  00194_short.nc
# 188                VM-150              153 KHz  00195_short.nc
# 189                VM-150              153 KHz  00196_short.nc
# 190                VM-150              153 KHz  00197_short.nc
# 191                VM-150              153 KHz  00198_short.nc
# 192              RD-VM150              150 KHz  00199_short.nc
# 193                VM-150                 None  00200_short.nc
# 194                VM-150                 None  00201_short.nc
# 195                VM-150                 None  00202_short.nc
# 196                VM-150              153 KHz  00203_short.nc
# 197                VM-150                 None  00204_short.nc
# 198                VM-150                 None  00205_short.nc
# 199                VM-150                 None  00206_short.nc
# 200                VM-150              153 KHz  00207_short.nc
# 201                VM-150              153 KHz  00208_short.nc
# 202                VM-150              153 KHz  00209_short.nc
# 203                VM-150              153 KHz  00210_short.nc
# 204                VM-150              153 KHz  00211_short.nc
# 208              RD-VM150              153 kHz  00215_short.nc
# 209              RD-VM150                 None  00216_short.nc
# 210              RD-VM150                 None  00217_short.nc
# 211              RD-VM150                 None  00218_short.nc
# 212              RD-VM150                 None  00219_short.nc
# 213                VM-150                 None  00221_short.nc
# 214                VM-150                 None  00222_short.nc
# 215                VM-150                 None  00223_short.nc
# 216                VM-150                 None  00224_short.nc
# 217                VM-150                 None  00225_short.nc
# 218                VM-150                 None  00231_short.nc
# 221                VM-150                 None  00234_short.nc
# 222                VM-150                 None  00235_short.nc
# 223                VM-150                 None  00236_short.nc
# 224              RD-VM150              153 kHz  00237_short.nc
# 225              RD-VM150              153 kHz  00238_short.nc
# 226              RD-VM150              153 kHz  00239_short.nc
# 227              RD-VM150              153 kHz  00240_short.nc
# 228              RD-VM150              153 kHz  00241_short.nc
# 229              RD-VM150              153 kHz  00242_short.nc
# 230              RD-VM150              153 kHz  00243_short.nc
# 231              RD-VM150              153 kHz  00244_short.nc
# 232              RD-VM150              153 kHz  00245_short.nc
# 233              RD-VM150              153 kHz  00246_short.nc
# 234              RD-VM150              153 kHz  00247_short.nc
# 235              RD-VM150              153 kHz  00248_short.nc
# 236                   150            153.6 kHz  00249_short.nc
# 237                   150            153.6 kHz  00250_short.nc
# 238                   150            153.6 kHz  00251_short.nc
# 239                   150            153.6 kHz  00252_short.nc
# 240                   150            153.6 kHz  00253_short.nc
# 241              RD-VM150              153 kHz  00254_short.nc
# 242                VM-150                 None  00255_short.nc
# 243                VM-150                 None  00256_short.nc
# 247              RD-VM150              153 kHz  00263_short.nc
# 248                VM-150                 None  00264_short.nc
# 249                VM-150                 None  00265_short.nc
# 250                VM-150                 None  00274_short.nc
# 251                VM-150                 None  00275_short.nc
# 252                VM-150                 None  00276_short.nc
# 253                VM-150                 None  00277_short.nc
# 255                VM-150                 None  00279_short.nc
# 259                VM-150                 None  00283_short.nc
# 260                VM-150                 None  00284_short.nc
# 262              RD-VM300              307 kHz  00288_short.nc
# 263              RD-VM300              307 kHz  00289_short.nc
# 264                VM-150                 None  00290_short.nc
# 265                VM-150                 None  00291_short.nc
# 266                VM-150                 None  00292_short.nc
# 267                VM-150              153 KHz  00293_short.nc
# 268                VM-150              153 KHz  00294_short.nc
# 269                VM-150              153 KHz  00295_short.nc
# 270                VM-150              153 KHz  00296_short.nc
# 271                VM-150              153 KHz  00297_short.nc
# 272                VM-150              153 KHz  00298_short.nc
# 273                VM-150              153 KHz  00299_short.nc
# 274                VM-150              153 KHz  00300_short.nc
# 275                VM-150              153 KHz  00301_short.nc
# 276                VM-150              153 KHz  00302_short.nc
# 277                VM-150              153 KHz  00303_short.nc
# 278                VM-150              153 KHz  00304_short.nc
# 279                VM-150              153 KHz  00305_short.nc
# 280                VM-150              153 KHz  00306_short.nc
# 281                VM-150              153 KHz  00307_short.nc
# 282                VM-150              153 KHz  00308_short.nc
# 283                VM-150              153 KHz  00309_short.nc
# 284                VM-150              153 KHz  00310_short.nc
# 285                VM-150              153 KHz  00311_short.nc
# 286                VM-150                 None  00322_short.nc
# 287                VM-150                 None  00323_short.nc
# 289              RD-VM150              153 kHz  00325_short.nc
# 290                   RDI                 None  00326_short.nc
# 291              RD-VM150              153 kHz  00327_short.nc
# 292                 RD-VM               150kHz  00328_short.nc
# 296                 RD-VM               150kHz  00332_short.nc
# 297                 RD-VM               150kHz  00333_short.nc
# 298                 RD-VM               150kHz  00334_short.nc
# 299              RD-VM150              153 kHz  00335_short.nc
# 300              RD-VM150              153 kHz  00336_short.nc
# 301                VM-150                 None  00337_short.nc
# 302                VM-150                 None  00338_short.nc
# 305                VM-150                 None  00341_short.nc
# 306   150 kHz hull mou...                 None  00342_short.nc
# 307   150 kHz hull mou...                 None  00343_short.nc
# 308   150 kHz hull mou...                 None  00344_short.nc
# 309   150 kHz hull mou...                 None  00345_short.nc
# 310              RD-VM150              153 kHz  00346_short.nc
# 311              RD-VM150              153 kHz  00347_short.nc
# 312              RD-VM150              153 kHz  00348_short.nc
# 313              RD-VM150              153 kHz  00349_short.nc
# 314              RD-VM150              153 kHz  00350_short.nc
# 335              RD-VM150              153 kHz  00371_short.nc
# 336              RD-VM150              153 kHz  00372_short.nc
# 338                VM-150                 None  00374_short.nc
# 339                VM-150                 None  00375_short.nc
# 340                VM-150                 None  00376_short.nc
# 341                VM-150                 None  00377_short.nc
# 342              RD-VM150              150 KHz  00378_short.nc
# 343                   150            153.6 kHz  00380_short.nc
# 344              RD-VM150              150 KHz  00381_short.nc
# 345              RD-VM150              150 KHz  00382_short.nc
# 355                VM-150                 None  00392_short.nc
# 356                VM-150                 None  00399_short.nc
# 366                VM-150            153.6 KHz  00409_short.nc
# 367                VM-150            153.6 KHz  00410_short.nc
# 368                VM-150            153.6 KHz  00411_short.nc
# 374                VM-150                 None  00417_short.nc
# 385                VM-150              153 KHz  00428_short.nc
# 386                VM-150              153 KHz  00429_short.nc
# 418                VM-150                 None  00461_short.nc
# 419                VM-150                 None  00462_short.nc
# 425              RD-VM150              153 kHz  00468_short.nc
# 428                   150            153.6 kHz  00471_short.nc
# 429                   150            153.6 kHz  00472_short.nc
# 430                   150            153.6 kHz  00473_short.nc
# 431                   150            153.6 kHz  00474_short.nc
# 432                   150            153.6 kHz  00475_short.nc
# 433                   150            153.6 kHz  00476_short.nc
# 434                   150            153.6 kHz  00477_short.nc
# 441              RD-VM150                  153  00485_short.nc
# 442              RD-VM150                  153  00486_short.nc
# 450                VM-150                 None  00494_short.nc
# 451                VM-150                 None  00495_short.nc
# 452                VM-150                 None  00496_short.nc
# 463                   RDI                 None  00508_short.nc
# 473   Ocean Surveyor I...               38 kHz  00518_short.nc
# 478                 VM150              150 Khz  00523_short.nc
# 479                VM-150              150 kHz  00524_short.nc
# 480                VM-150              150 kHz  00525_short.nc
# 481              RD-VM150              150 KHz  00526_short.nc
# 482              RD-VM150              150 KHz  00527_short.nc
# 483                 VM150              150 Khz  00528_short.nc
# 484                VM-150                 None  00529_short.nc
# 485                VM-150                 None  00530_short.nc
# 486                VM-150                 None  00531_short.nc
# 487                VM-150                 None  00532_short.nc
# 488                VM-150                 None  00533_short.nc
# 489                VM-150              150 kHz  00534_short.nc
# 497                VM-150              150 kHz  00542_short.nc
# 498                   150            153.6 kHz  00543_short.nc
# 501                   150            153.6 kHz  00546_short.nc
# 502              RD-VM150              150 KHz  00547_short.nc
# 503              RD-VM150              150 KHz  00548_short.nc
# 504              RD-VM150              150 KHz  00549_short.nc
# 505              RD-VM150              150 KHz  00550_short.nc
# 506              RD-VM150              150 KHz  00551_short.nc
# 509              RD-VM150              150 KHz  00554_short.nc
# 511                VM-150                 None  00556_short.nc
# 512                VM-150                 None  00557_short.nc
# 513                VM-150                 None  00558_short.nc
# 514                VM-150                 None  00559_short.nc
# 515                VM-150                 None  00560_short.nc
# 516                VM-150                 None  00561_short.nc
# 517                VM-150                 None  00562_short.nc
# 518                VM-150                 None  00563_short.nc
# 519                VM-150                 None  00564_short.nc
# 520                VM-150                 None  00565_short.nc
# 521                VM-150                 None  00566_short.nc
# 522                VM-150                 None  00567_short.nc
# 523                VM-150                 None  00568_short.nc
# 524                VM-150                 None  00569_short.nc
# 525                VM-150                 None  00570_short.nc
# 526                VM-150              153 KHz  00571_short.nc
# 527                VM-150                 None  00572_short.nc
# 529                VM-150                 None  00574_short.nc
# 530                VM-150                 None  00575_short.nc
# 531                VM-150                 None  00576_short.nc
# 532                VM-150                 None  00577_short.nc
# 533                VM-150                 None  00578_short.nc
# 534                VM-150                 None  00579_short.nc
# 535                VM-150                 None  00580_short.nc
# 536                VM-150                 None  00581_short.nc
# 537                VM-150                 None  00582_short.nc
# 538                VM-150                 None  00583_short.nc
# 539                VM-150                 None  00584_short.nc
# 540                VM-150                 None  00585_short.nc
# 541                VM-150                 None  00586_short.nc
# 542                VM-150                 None  00587_short.nc
# 543                VM-150                 None  00588_short.nc
# 544                VM-150                 None  00589_short.nc
# 545                VM-150                 None  00590_short.nc
# 546                VM-150                 None  00591_short.nc
# 547                VM-150                 None  00592_short.nc
# 548                VM-150                 None  00593_short.nc
# 549                VM-150                 None  00594_short.nc
# 551                VM-150                 None  00596_short.nc
# 552                VM-150                 None  00597_short.nc
# 553                VM-150                 None  00598_short.nc
# 556                VM-150                 None  00601_short.nc
# 557                VM-150                 None  00602_short.nc
# 558                VM-150                 None  00603_short.nc
# 559                VM-150                 None  00604_short.nc
# 563                VM-150            153.6 kHz  00611_short.nc
# 564                VM-150            153.6 kHz  00612_short.nc
# 565                VM-150            153.6 kHz  00613_short.nc
# 566                VM-150            153.6 kHz  00614_short.nc
# 567                VM-150            153.6 kHz  00615_short.nc
# 568              RD-VM150                  153  00616_short.nc
# 571                VM-150            153.6 kHz  00619_short.nc
# 572                VM-150            153.6 kHz  00620_short.nc
# 573                VM-150            153.6 kHz  00621_short.nc
# 574                VM-150            153.6 kHz  00622_short.nc
# 575                VM-150            153.6 kHz  00623_short.nc
# 576                VM-150            153.6 kHz  00624_short.nc
# 577                VM-150            153.6 kHz  00625_short.nc
# 578                VM-150            153.6 kHz  00626_short.nc
# 579                VM-150            153.6 kHz  00627_short.nc
# 580                VM-150            153.6 kHz  00628_short.nc
# 581                VM-150            153.6 kHz  00629_short.nc
# 582                VM-150            153.6 kHz  00630_short.nc
# 583                VM-150            153.6 kHz  00631_short.nc
# 584                VM-150            153.6 kHz  00632_short.nc
# 585                VM-150            153.6 kHz  00633_short.nc
# 586                VM-150                 None  00634_short.nc
# 587                VM-150                 None  00635_short.nc
# 588                VM-150                 None  00636_short.nc
# 590                VM-150                 None  00638_short.nc
# 591                 RD-VM               150kHz  00639_short.nc
# 595                VM-150              153 KHz  00643_short.nc
# 598                VM-150            153.6 kHz  00646_short.nc
# 599                VM-150            153.6 kHz  00647_short.nc
# 600                VM-150            153.6 kHz  00648_short.nc
# 601                VM-150            153.6 kHz  00649_short.nc
# 602                VM-150            153.6 kHz  00650_short.nc
# 603                VM-150            153.6 kHz  00651_short.nc
# 605                VM-150                 None  00653_short.nc
# 606                VM-150                 None  00654_short.nc
# 607                VM-150                 None  00655_short.nc
# 608                VM-150                 None  00656_short.nc
# 609                VM-150                 None  00657_short.nc
# 610                VM-150                 None  00658_short.nc
# 611                VM-150                 None  00659_short.nc
# 612                VM-150                 None  00660_short.nc
# 613                VM-150                 None  00661_short.nc
# 614                VM-150                 None  00662_short.nc
# 615                VM-150                 None  00664_short.nc
# 616                VM-150                 None  00665_short.nc
# 617                VM-150                 None  00666_short.nc
# 618                VM-150                 None  00667_short.nc
# 619                VM-150                 None  00668_short.nc
# 620                VM-150                 None  00669_short.nc
# 621                VM-150                 None  00670_short.nc
# 622                VM-150                 None  00671_short.nc
# 623                VM-150                 None  00672_short.nc
# 624                VM-150                 None  00673_short.nc
# 625                VM-150                 None  00674_short.nc
# 626                VM-150                 None  00675_short.nc
# 627                VM-150                 None  00676_short.nc
# 628                VM-150                 None  00677_short.nc
# 629                VM-150                 None  00678_short.nc
# 630                VM-150                 None  00679_short.nc
# 631                VM-150                 None  00680_short.nc
# 632                VM-150                 None  00681_short.nc
# 633                VM-150                 None  00682_short.nc
# 634                VM-150                 None  00683_short.nc
# 635                VM-150                 None  00684_short.nc
# 636                VM-150                 None  00685_short.nc
# 637                VM-150                 None  00686_short.nc
# 638                VM-150                 None  00687_short.nc
# 639                VM-150                 None  00688_short.nc
# 640                VM-150                 None  00689_short.nc
# 641                VM-300                 None  00690_short.nc
# 642                VM-300                 None  00691_short.nc
# 664                VM-150                 None  00713_short.nc
# 665                VM-150                 None  00714_short.nc
# 666                VM-150                 None  00715_short.nc
# 667                VM-150                 None  00716_short.nc
# 668                VM-150                 None  00717_short.nc
# 669                VM-300                 None  00718_short.nc
# 670                VM-300                 None  00719_short.nc
# 671                VM-300                 None  00720_short.nc
# 672                VM-300                 None  00721_short.nc
# 673                VM-300                 None  00722_short.nc
# 674                VM-150                 None  00723_short.nc
# 676   RDI 75KHz Ocean ...                 None  00725_short.nc
# 677   RDI 75KHz Ocean ...                 None  00726_short.nc
# 678                VM-150                 None  00727_short.nc
# 679                VM-150                 None  00728_short.nc
# 680                VM-150                 None  00729_short.nc
# 681                VM-150              153 KHz  00730_short.nc
# 682                VM-150              153 KHz  00731_short.nc
# 683                VM-150              153 KHz  00732_short.nc
# 684                VM-150              153 KHz  00733_short.nc
# 685                VM-150              153 KHz  00734_short.nc
# 686                VM-150              153 KHz  00735_short.nc
# 687                VM-150              153 KHz  00736_short.nc
# 688                VM-150              153 KHz  00737_short.nc
# 689                VM-150              153 KHz  00738_short.nc
# 690                VM-150              153 KHz  00739_short.nc
# 691                VM-150              153 KHz  00740_short.nc
# 692                VM-150              153 KHz  00741_short.nc
# 693                VM-150              153 KHz  00742_short.nc
# 694                VM-150              153 KHz  00743_short.nc
# 695                VM-150              153 KHz  00744_short.nc
# 696                VM-150              153 KHz  00745_short.nc
# 697                VM-150              153 KHz  00746_short.nc
# 698                VM-150              153 KHz  00747_short.nc
# 699                VM-150              153 KHz  00748_short.nc
# 700                VM-150              153 KHz  00749_short.nc
# 701                VM-150              153 KHz  00750_short.nc
# 702                VM-150              153 KHz  00751_short.nc
# 703                VM-150              153 KHz  00752_short.nc
# 704                VM-150              153 KHz  00753_short.nc
# 705                VM-150              153 KHz  00754_short.nc
# 706                VM-150              153 KHz  00756_short.nc
# 707                VM-150              153 KHz  00757_short.nc
# 708                VM-150              153 KHz  00758_short.nc
# 709                VM-150              153 KHz  00759_short.nc
# 710                VM-150              153 KHz  00760_short.nc
# 711                VM-150              153 KHz  00761_short.nc
# 712                VM-150              153 KHz  00762_short.nc
# 713                VM-150              153 KHz  00763_short.nc
# 714                VM-150              153 KHz  00764_short.nc
# 715                VM-150              153 KHz  00765_short.nc
# 716                VM-150              153 KHz  00766_short.nc
# 717                VM-150              153 KHz  00767_short.nc
# 718                VM-150              153 KHz  00768_short.nc
# 719                VM-150              153 KHz  00769_short.nc
# 720                VM-150              153 KHz  00770_short.nc
# 721                VM-150              153 KHz  00771_short.nc
# 722                VM-150              153 KHz  00772_short.nc
# 723                VM-150              153 KHz  00773_short.nc
# 724                VM-150              153 KHz  00774_short.nc
# 725                VM-150              153 KHz  00775_short.nc
# 726                VM-150              153 KHz  00776_short.nc
# 727                VM-150              153 KHz  00777_short.nc
# 728                VM-150              153 KHz  00778_short.nc
# 729                VM-150              153 KHz  00779_short.nc
# 730                VM-150              153 KHz  00780_short.nc
# 731                VM-150              153 KHz  00781_short.nc
# 732                VM-150              153 KHz  00782_short.nc
# 733                VM-150            153.6 kHz  00783_short.nc
# 734                VM-150            153.6 kHz  00784_short.nc
# 735                VM-150            153.6 kHz  00785_short.nc
# 736                VM-150            153.6 kHz  00786_short.nc
# 737                VM-150            153.6 kHz  00787_short.nc
# 752   153.6 kHz hull m...                 None  00802_short.nc
# 757                VM-150            153.6 kHz  00807_short.nc
# 758                VM-150            153.6 kHz  00808_short.nc
# 759                VM-150            153.6 kHz  00809_short.nc
# 760                VM-150            153.6 kHz  00810_short.nc
# 761                VM-150            153.6 kHz  00811_short.nc
# 762                VM-150            153.6 kHz  00812_short.nc
# 763                VM-150            153.6 kHz  00813_short.nc
# 764                VM-150            153.6 kHz  00814_short.nc
# 765                VM-150            153.6 kHz  00815_short.nc
# 766                VM-150            153.6 kHz  00816_short.nc
# 767                VM-150            153.6 kHz  00817_short.nc
# 768                VM-150            153.6 kHz  00818_short.nc
# 769                VM-150            153.6 kHz  00819_short.nc
# 770                VM-150            153.6 kHz  00820_short.nc
# 771                VM-150            153.6 kHz  00821_short.nc
# 772                VM-150            153.6 kHz  00822_short.nc
# 773                VM-150            153.6 kHz  00823_short.nc
# 774                VM-150            153.6 kHz  00824_short.nc
# 775                VM-150            153.6 kHz  00825_short.nc
# 776                VM-150            153.6 kHz  00826_short.nc
# 777                VM-150            153.6 kHz  00827_short.nc
# 782                VM-150                 None  00832_short.nc
# 783                VM-150                 None  00833_short.nc
# 784                VM-150                 None  00834_short.nc
# 785                VM-150                 None  00835_short.nc
# 786                VM-150                 None  00836_short.nc
# 787                VM-150                 None  00837_short.nc
# 788                VM-150                 None  00838_short.nc
# 797                VM-150                 None  00847_short.nc
# 798                VM-150                 None  00848_short.nc
# 799                VM-150                 None  00849_short.nc
# 800                VM-150                 None  00850_short.nc
# 801                VM-150                 None  00851_short.nc
# 802                VM-150                 None  00852_short.nc
# 803                VM-150                 None  00853_short.nc
# 804                VM-150                 None  00854_short.nc
# 805                VM-150                 None  00855_short.nc
# 806                VM-150                 None  00856_short.nc
# 807                VM-150                 None  00857_short.nc
# 808                VM-150                 None  00858_short.nc
# 809                VM-150                 None  00859_short.nc
# 810                VM-150                 None  00860_short.nc
# 811                VM-150                 None  00861_short.nc
# 812                VM-150                 None  00862_short.nc
# 838                  OS75               75 KHz  00888_short.nc
# 839                  OS75               75 KHz  00889_short.nc
# 840                  OS75               75 KHz  00890_short.nc
# 841                  OS75               75 KHz  00891_short.nc
# 842                  OS75               75 KHz  00892_short.nc
# 843                  OS75               75 KHz  00893_short.nc
# 846                  OS75               75 KHz  00896_short.nc
# 847                  OS75               75 KHz  00897_short.nc
# 848                  OS75               75 KHz  00898_short.nc
# 899              RD-VM150              153 kHz  00949_short.nc
# 900              RD-VM150              153 kHz  00950_short.nc
# 901              RD-VM150              153 kHz  00951_short.nc
# 902              RD-VM150              153 kHz  00952_short.nc
# 903              RD-VM150              153 kHz  00953_short.nc
# 904              RD-VM150              153 kHz  00954_short.nc
# 905              RD-VM150              153 kHz  00955_short.nc
# 906              RD-VM150              153 kHz  00956_short.nc
# 907              RD-VM150              153 kHz  00957_short.nc
# 908              RD-VM150              153 kHz  00958_short.nc
# 909              RD-VM150              153 kHz  00959_short.nc
# 910              RD-VM150              153 kHz  00960_short.nc
# 911              RD-VM150              153 kHz  00961_short.nc
# 912              RD-VM150              153 kHz  00962_short.nc
# 913              RD-VM150              153 kHz  00963_short.nc
# 914              RD-VM150              153 kHz  00964_short.nc
# 915              RD-VM150              153 kHz  00965_short.nc
# 916              RD-VM150              153 kHz  00966_short.nc
# 917              RD-VM150              153 kHz  00967_short.nc
# 918              RD-VM150              153 kHz  00968_short.nc
# 919              RD-VM150              153 kHz  00969_short.nc
# 920              RD-VM150              153 kHz  00970_short.nc
# 921              RD-VM150              153 kHz  00971_short.nc
# 922              RD-VM150              153 kHz  00972_short.nc
# 923              RD-VM150              153 kHz  00973_short.nc
# 924              RD-VM150              153 kHz  00974_short.nc
# 925              RD-VM150              153 kHz  00975_short.nc
# 926              RD-VM150              153 kHz  00976_short.nc
# 927              RD-VM150              153 kHz  00977_short.nc
# 928              RD-VM150              153 kHz  00978_short.nc
# 929              RD-VM150              153 kHz  00979_short.nc
# 954   Ocean Surveyor OS75              76.8KHz  01010_short.nc
# 962   Ocean Surveyor I...               38 kHz  01018_short.nc
# 963   Ocean Surveyor I...               38 kHz  01019_short.nc
# 964   Ocean Surveyor I...               38 kHz  01020_short.nc
# 965   Ocean Surveyor I...               38 kHz  01021_short.nc
# 966   Ocean Surveyor I...               38 kHz  01022_short.nc
# 967                VM-150            153.6 kHz  01023_short.nc
# 968                VM-150            153.6 kHz  01024_short.nc
# 969                VM-150            153.6 kHz  01025_short.nc
# 970                VM-150            153.6 kHz  01026_short.nc
# 971                VM-150            153.6 kHz  01027_short.nc
# 972                VM-150            153.6 kHz  01028_short.nc
# 973                VM-150            153.6 kHz  01029_short.nc
# 974                VM-150            153.6 kHz  01030_short.nc
# 975                VM-150            153.6 kHz  01031_short.nc
# 977                VM-150            153.6 kHz  01033_short.nc
# 978   Ocean Surveyor OS75              76.8KHz  01034_short.nc
# 1011  Ocean Surveyor OS75              76.8KHz  01067_short.nc
# 1012  Ocean Surveyor OS75              76.8KHz  01068_short.nc
# 1013  Ocean Surveyor OS75              76.8KHz  01069_short.nc
# 1014             RD-VM150              150 KHz  01071_short.nc
# 1015             RD-VM150              150 KHz  01072_short.nc
# 1016             RD-VM150              150 KHz  01073_short.nc
# 1027    Ocean Surveyer 75                 None  01084_short.nc
# 1042               VM-150            153.6 KHz  01099_short.nc
# 1043               VM-150            153.6 KHz  01100_short.nc
# 1044               VM-150            153.6 KHz  01101_short.nc
# 1045               VM-150            153.6 KHz  01102_short.nc
# 1046               VM-150            153.6 KHz  01103_short.nc
# 1047               VM-150            153.6 KHz  01104_short.nc
# 1048               VM-150            153.6 KHz  01105_short.nc
# 1049               VM-150            153.6 KHz  01106_short.nc
# 1050               VM-150            153.6 KHz  01107_short.nc
# 1051               VM-150            153.6 KHz  01108_short.nc
# 1052               VM-150            153.6 KHz  01109_short.nc
# 1053               VM-150            153.6 KHz  01110_short.nc
# 1054               VM-150            153.6 KHz  01111_short.nc
# 1055               VM-150            153.6 KHz  01112_short.nc
# 1056               VM-150            153.6 KHz  01113_short.nc
# 1057               VM-150            153.6 KHz  01114_short.nc
# 1058               VM-150            153.6 KHz  01115_short.nc
# 1059               VM-150            153.6 KHz  01116_short.nc
# 1060               VM-150            153.6 KHz  01117_short.nc
# 1061               VM-150            153.6 KHz  01118_short.nc
# 1062               VM-150            153.6 KHz  01119_short.nc
# 1063               VM-150            153.6 KHz  01120_short.nc
# 1064               VM-150            153.6 KHz  01121_short.nc
# 1065               VM-150            153.6 KHz  01122_short.nc
# 1066               VM-150            153.6 KHz  01123_short.nc
# 1067               VM-150            153.6 KHz  01124_short.nc
# 1068               VM-150            153.6 KHz  01125_short.nc
# 1069               VM-150            153.6 KHz  01126_short.nc
# 1070               VM-150            153.6 KHz  01127_short.nc
# 1071               VM-150            153.6 KHz  01128_short.nc
# 1072               VM-150            153.6 KHz  01129_short.nc
# 1073               VM-150            153.6 KHz  01130_short.nc
# 1074               VM-150            153.6 KHz  01131_short.nc
# 1075               VM-150            153.6 KHz  01132_short.nc
# 1076               VM-150            153.6 KHz  01133_short.nc
# 1077               VM-150            153.6 KHz  01134_short.nc
# 1135  Ocean Surveyor OS75              76.8KHz  01192_short.nc
# 1136  Ocean Surveyor OS75              76.8KHz  01193_short.nc
# 1137  Ocean Surveyor OS75              76.8KHz  01194_short.nc
# 1138  Ocean Surveyor OS75              76.8KHz  01195_short.nc
# 1220  75KHz Ocean Surv...                 None  01277_short.nc
# 1227               VM-150                 None  01284_short.nc
# 1289    Ocean Surveyor 75               75 kHz  01358_short.nc
# 1290    Ocean Surveyor 75               75 kHz  01359_short.nc
# 1291    Ocean Surveyor 75               75 kHz  01360_short.nc
# 1292    Ocean Surveyor 75               75 kHz  01361_short.nc
# 1302               VM-150            153.6 KHz  01371_short.nc
# 1316  Workhorse Marine...              300 kHz  01385_short.nc
# 1317  Workhorse Marine...              300 kHz  01386_short.nc
# 1318  Workhorse Marine...              300 kHz  01387_short.nc
# 1484        WorkHorse 300               300kHz  01568_short.nc
# 1638  Ocean Surveyor OS75              76.8KHz  01722_short.nc
# 1639  Ocean Surveyor OS75              76.8KHz  01723_short.nc
# 1974  Workhorse 300; 3...                 None  02086_short.nc
# 2015  WorkHorse Marine...              600 kHz  02128_short.nc
# 2078  Workhorse 300; 3...                 None  02191_short.nc
# 2081  Workhorse 300; 3...                 None  02194_short.nc
# 2082  Workhorse 300; 3...                 None  02195_short.nc
# 2087  Workhorse 300; 3...                 None  02200_short.nc
# 2088  Workhorse 300; 3...                 None  02201_short.nc
# 2101  Workhorse 300; 3...                 None  02214_short.nc
# 2102  Workhorse 300; 3...                 None  02215_short.nc
# 2103  Workhorse 300; 3...                 None  02216_short.nc
# 2107  Workhorse 300; 3...                 None  02220_short.nc
# 2139  Workhorse 300; 3...                 None  02258_short.nc
# 2140  Workhorse 300; 3...                 None  02259_short.nc
# 2141  Workhorse 300; 3...                 None  02261_short.nc
# 2144  Workhorse 300; 3...                 None  02265_short.nc
# 2151  Workhorse 300; 3...                 None  02272_short.nc
# 2158  Workhorse 300; 3...                 None  02281_short.nc
# 2159  Workhorse 300; 3...                 None  02282_short.nc
# 2267  OS75 (Ocean Surv...               75 kHz  02390_short.nc
# 2268  OS75 (Ocean Surv...               75 kHz  02391_short.nc
# 2269  OS75 (Ocean Surv...               75 kHz  02392_short.nc
# 2270  OS75 (Ocean Surv...               75 kHz  02393_short.nc
# 2271  OS75 (Ocean Surv...               75 kHz  02394_short.nc
# 2272  OS75 (Ocean Surv...               75 kHz  02395_short.nc
# 2273  OS75 (Ocean Surv...               75 kHz  02396_short.nc
# 2274  OS75 (Ocean Surv...               75 kHz  02397_short.nc
# 2275  OS75 (Ocean Surv...               75 kHz  02398_short.nc
# 2276  OS75 (Ocean Surv...               75 kHz  02399_short.nc
#
#           cruise_beg_date   beam_width bw_from_all_text bw_from_comments  \
# 0    1992-11-08 02:21:...         None             None             None
# 1    1992-12-12 02:18:...         None             None             None
# 2    1993-01-23 09:47:...         None             None             None
# 3    1992-10-27 23:36:...         None             None             None
# 4    1992-12-02 07:00:...  3 deg (???)             None             None
# 5    1993-01-22 23:11:...         None             None             None
# 6    1993-03-03 08:48:...         None             None             None
# 7    1993-04-04 05:14:...         None             None             None
# 8    1993-04-21 22:02:...         None             None             None
# 9    1993-06-04 21:41:...         None             None             None
# 10   1993-06-21 00:27:...         None             None             None
# 11   1992-12-13 02:00:...         None             None             None
# 12   1992-10-06 02:33:...         None             None             None
# 14   1993-02-22 21:39:...         None             None             None
# 15   1993-06-29 13:59:...         None             None             None
# 16   1993-08-13 20:34:...         None             None             None
# 17   1993-11-13 22:50:...         None             None             None
# 18   1991-05-31 15:33:...         None             None             None
# 19   1991-07-17 04:03:...         None             None             None
# ...
# 149   some bottom inte...
# 150   some bottom inte...
# 151   This data is of ...
# 152   Signal loss only...
# 153   some bottom inte...
# 154   some bottom inte...
# 155   some bottom inte...
# 156   some bottom inte...
# 157   On station and u...
# 158   No air bubble pr...
# 159   There are numero...
# 161   This data is of ...
# 162   This data is of ...
# 163   Purpose was to s...
# 164   transducer tempe...
# 165   transducer tempe...
# 166   time was behind ...
# 167   some bottom inte...
# 169   some bottom inte...
# 179   some bottom inte...
# 180   some bottom inte...
# 181   some bottom inte...
# 182   some bottom inte...
# 183          hull mounted
# 184          hull mounted
# 185   All 3-beam solut...
# 186   transducer tempe...
# 187   purpose of the c...
# 188   DATA DID NOT REC...
# 189   A second similar...
# 190   Each beam is ori...
# 191   transducer tempe...
# 192   This was a curre...
# 193   some bottom inte...
# 194   some bottom inte...
# 195   some bottom inte...
# 196   This cruise was ...
# 197                    ok
# 198   5-minute ensembl...
# 199          hull mounted
# 200   some bottom inte...
# 201   some bottom inte...
# 202   Configuration hi...
# 203                    ok
# 204                    ok
# 208   There are some p...
# 209   time correction ...
# 210   time correction ...
# 211   time correction ...
# 212   time correction ...
# 213   rough weather///...
# 214   rough weather; s...
# 215   cruise to statio...
# 216   New transducer i...
# 217   New transducer i...
# 218   New transducer 1...
# 221   transducer repla...
# 222   transducer repla...
# 223   transducer repla...
# 224   The first of the...
# 225   The purpose of t...
# 226   The purpose of t...
# 227   The purpose of t...
# 228   This cruise was ...
# 229   This cruise was ...
# 230   The second of th...
# 231   The purpose of c...
# 232   The third proces...
# 233   This cruise was ...
# 234   TN049 was the fo...
# 235   The fifth proces...
# 236   The scientific o...
# 237   Detailed hydrogr...
# 238   Emphasis was the...
# 239   The cruise empha...
# 240   The central topi...
# 241                  None
# 242   transducer repla...
# 243   northbound trans...
# 247   There were four ...
# 248   transducer repla...
# 249   transducer repla...
# 250   transducer repla...
# 251   transducer repla...
# 252   transducer repla...
# 253   transducer repla...
# 255   transducer repla...
# 259   transducer repla...
# 260   transducer repla...
# 262   The NODC subset ...
# 263   Transducer belon...
# 264   transducer repla...
# 265   transducer repla...
# 266   transducer repla...
# 267                    ok
# 268                    ok
# 269                    ok
# 270                    ok
# 271                    ok
# 272                    ok
# 273                    ok
# 274                    ok
# 275                    ok
# 276   Thermistor data ...
# 277                    ok
# 278                    ok
# 279                    ok
# 280   Thermistor data ...
# 281   Thermistor data ...
# 282   Thermistor data ...
# 283   Thermistor data ...
# 284   Thermistor data ...
# 285   Thermistor data ...
# 286   transducer repla...
# 287   transducer repla...
# 289                  None
# 290   The data have be...
# 291   The data have be...
# 292   Positions from a...
# 296   Positions from a...
# 297   Positions from a...
# 298   Positions from a...
# 299   Data not availab...
# 300   Data not availab...
# 301   Beam 2 low WRT o...
# 302   Beam 2 low WRT o...
# 305   Beam 2 low WRT o...
# 306   firmware version...
# 307   firmware version...
# 308   K.Heywood/M.Hart...
# 309   Affiliated with ...
# 310     data quality good
# 311     data quality good
# 312     data quality good
# 313     data quality good
# 314     data quality good
# 335   UE3 only made to...
# 336                  None
# 338   Beam 2 low WRT o...
# 339   Beam 2 low WRT o...
# 340   Beam 2 low WRT o...
# 341   Up to nine 60-kH...
# 342   Position, speed,...
# 343   Excepts below fr...
# 344   Only Agulhas tra...
# 345   Position, speed,...
# 355   Beam 2 low WRT o...
# 356   Beam 2 low WRT o...
# 366                  None
# 367   xducer in fresh ...
# 368   xducer in fresh ...
# 374   Beam 2 low WRT o...
# 385                  None
# 386                  None
# 418   Beam 2 low WRT o...
# 419   Beam 2 low WRT o...
# 425   There were four ...
# 428   Excepts below fr...
# 429   Excepts below fr...
# 430                    OK
# 431                    OK
# 432                    OK
# 433                    OK
# 434                    OK
# 441   prior to 3/30,00...
# 442   prior to 6/14,22...
# 450   Beam 2 low WRT o...
# 451   Beam 2 low WRT o...
# 452   Beam 2 low WRT o...
# 463   The data have be...
# 473   4 beams angled o...
# 478   ADCP generally p...
# 479                    OK
# 480                    OK
# 481   In the CODAS dat...
# 482   In the CODAS dat...
# 483   ADCP generally p...
# 484   Temperature look...
# 485   Temperature look...
# 486   Temperature look...
# 487   Temperature look...
# 488   The four beams r...
# 489   Summary of scien...
# 497   Summary of scien...
# 498                  None
# 501                    OK
# 502   In the CODAS dat...
# 503   On the///Positio...
# 504   a few extreme sh...
# 505   a few extreme sh...
# 506   Position, speed,...
# 509   Signal loss only...
# 511   Temperature look...
# 512   Temperature look...
# 513   may be a gyro pr...
# 514   gyro problems///...
# 515   The four beams r...
# 516   The four beams r...
# 517   All 4 beams retu...
# 518   All 4 beams retu...
# 519   All 4 beams retu...
# 520   new transducer, ...
# 521   new transducer p...
# 522   new transducer p...
# 523   new transducer p...
# 524   new transducer p...
# 525   new transducer p...
# 526   data did not sta...
# 527   new transducer p...
# 529   Up to nine 60-kH...
# 530   All 4 beams retu...
# 531   All 4 beams retu...
# 532   All 4 beams retu...
# 533   All 4 beams retu...
# 534   All 4 beams retu...
# 535   All 4 beams retu...
# 536   All 4 beams retu...
# 537   All 4 beams retu...
# 538   All 4 beams retu...
# 539   All 4 beams retu...
# 540   All 4 beams retu...
# 541   All 4 beams retu...
# 542   All 4 beams retu...
# 543   All 4 beams retu...
# 544   All 4 beams retu...
# 545   All 4 beams retu...
# 546   All 4 beams retu...
# 547   All 4 beams retu...
# 548   All 4 beams retu...
# 549   All 4 beams retu...
# 551   All 4 beams retu...
# 552   All 4 beams retu...
# 553   All 4 beams retu...
# 556   All 4 beams retu...
# 557   Only 4-5 bins of...
# 558   All 4 beams retu...
# 559   All 4 beams retu...
# 563   The transducer i...
# 564   The transducer i...
# 565   The transducer i...
# 566   The transducer i...
# 567   The transducer i...
# 568   prior to 7/9,18:...
# 571   The transducer i...
# 572   The transducer i...
# 573   The transducer i...
# 574   The transducer i...
# 575   The transducer i...
# 576   The transducer i...
# 577   The transducer i...
# 578   The transducer i...
# 579   The transducer i...
# 580   The transducer i...
# 581   The transducer i...
# 582   The transducer i...
# 583   The transducer i...
# 584   The transducer i...
# 585   The transducer i...
# 586   All 4 beams had ...
# 587   All 4 beams had ...
# 588   All 4 beams had ...
# 590   All 4 beams had ...
# 591   also a Continuou...
# 595   OK///Temperature...
# 598   The transducer i...
# 599   The transducer i...
# 600   The transducer i...
# 601   The transducer i...
# 602   The transducer i...
# 603   The transducer i...
# 605          hull mounted
# 606          hull mounted
# 607          hull mounted
# 608          hull mounted
# 609          hull mounted
# 610          hull mounted
# 611          hull mounted
# 612          hull mounted
# 613          hull mounted
# 614          hull mounted
# 615          hull mounted
# 616   hull mounted///b...
# 617          hull mounted
# 618          hull mounted
# 619          hull mounted
# 620   Moorings and CTD...
# 621          hull mounted
# 622   Moorings, CTD///...
# 623   Moorings, CTD///...
# 624   Moorings, CTD///...
# 625   Moorings, CTD///...
# 626          hull mounted
# 627          hull mounted
# 628          hull mounted
# 629          hull mounted
# 630   GLOBEC Moorings/...
# 631   GLOBEC Moorings/...
# 632          hull mounted
# 633          hull mounted
# 634          hull mounted
# 635          hull mounted
# 636          hull mounted
# 637          hull mounted
# 638          hull mounted
# 639          hull mounted
# 640   mooring cruise//...
# 641   broadscale cruis...
# 642   broadscale cruis...
# 664   process cruise//...
# 665   mooring cruise//...
# 666   mooring cruise//...
# 667   mooring cruise//...
# 668   mooring/process ...
# 669   broad-scale crui...
# 670   broad-scale crui...
# 671   broad-scale crui...
# 672   broad-scale crui...
# 673   broad-scale crui...
# 674   process cruise//...
# 676                  None
# 677                  None
# 678   long port call i...
# 679   long port call i...
# 680   Up to nine 60-kH...
# 681   no big gaps in f...
# 682   Some data delete...
# 683   no big gaps in f...
# 684   Also leg to NE o...
# 685   editing applied/...
# 686   editing applied/...
# 687   editing applied/...
# 688   editing applied/...
# 689   editing applied/...
# 690   editing applied/...
# 691   editing applied/...
# 692   editing applied/...
# 693   editing applied/...
# 694   editing applied/...
# 695   editing applied/...
# 696   editing applied/...
# 697   TC9401_1 (leg 1)...
# 698   editing applied/...
# 699   editing applied/...
# 700   editing applied/...
# 701   All 3-beam solut...
# 702   editing applied/...
# 703   editing applied/...
# 704   editing applied/...
# 705   editing applied/...
# 706   editing applied/...
# 707   editing applied/...
# 708   editing applied/...
# 709   editing applied/...
# 710   editing applied/...
# 711   editing applied/...
# 712   editing applied/...
# 713   editing applied/...
# 714   editing applied/...
# 715   Ashtech heading ...
# 716   no Ashtech headi...
# 717   no Ashtech headi...
# 718   no Ashtech headi...
# 719   no Ashtech headi...
# 720   Ashtech heading ...
# 721   Ashtech heading ...
# 722   Ashtech heading ...
# 723   Ashtech heading ...
# 724   Ashtech heading ...
# 725   Ashtech heading ...
# 726   Ashtech heading ...
# 727   editing applied/...
# 728   editing applied/...
# 729   editing applied/...
# 730   editing applied/...
# 731   editing applied/...
# 732   partial ashtec c...
# 733   The transducer i...
# 734   The transducer i...
# 735   The transducer i...
# 736   The transducer i...
# 737   The transducer i...
# 752   firmware version...
# 757   The transducer i...
# 758   The transducer i...
# 759   The transducer i...
# 760   The transducer i...
# 761   The transducer i...
# 762   The transducer i...
# 763   The transducer i...
# 764   The transducer i...
# 765   The transducer i...
# 766   The transducer i...
# 767   The transducer i...
# 768   The transducer i...
# 769   The transducer i...
# 770   The transducer i...
# 771   The transducer i...
# 772   The transducer i...
# 773   The transducer i...
# 774   The transducer i...
# 775   The transducer i...
# 776   The transducer i...
# 777   The transducer i...
# 782   Temperature look...
# 783   Temperature look...
# 784   Temperature look...
# 785   Temperature look...
# 786   Temperature look...
# 787   Temperature look...
# 788   Temperature look...
# 797   Up to nine 60-kH...
# 798   Up to nine 60-kH...
# 799   Up to nine 60-kH...
# 800   Up to nine 60-kH...
# 801   Up to nine 60-kH...
# 802   Up to nine 60-kH...
# 803   Up to nine 60-kH...
# 804   Lots of very sha...
# 805   cruise terminate...
# 806   Up to nine 60-kH...
# 807   Up to nine 60-kH...
# 808   Up to nine 60-kH...
# 809   Up to nine 60-kH...
# 810   Up to nine 60-kH...
# 811   Up to nine 60-kH...
# 812   Up to nine 60-kH...
# 838   Mooring cruise c...
# 839   Mooring cruise c...
# 840   Mooring cruise c...
# 841   Mooring cruise c...
# 842   Mooring cruise c...
# 843   Mooring cruise c...
# 846   Mooring cruise c...
# 847   Mooring cruise c...
# 848   Mooring cruise c...
# 899                  None
# 900                  None
# 901                  None
# 902                  None
# 903                  None
# 904                  None
# 905                  None
# 906                  None
# 907                  None
# 908                  None
# 909                  None
# 910                  None
# 911                  None
# 912                  None
# 913                  None
# 914                  None
# 915                  None
# 916                  None
# 917                  None
# 918                  None
# 919                  None
# 920                  None
# 921                  None
# 922                  None
# 923                  None
# 924                  None
# 925                  None
# 926                  None
# 927                  None
# 928                  None
# 929                  None
# 954                  None
# 962   This dataset is ...
# 963   This dataset is ...
# 964   This dataset is ...
# 965   4 beams angled o...
# 966   4 beams angled o...
# 967   The transducer i...
# 968   The transducer i...
# 969   The transducer i...
# 970   The transducer i...
# 971   The transducer i...
# 972   The transducer i...
# 973   The transducer i...
# 974   The transducer i...
# 975   The transducer i...
# 977   The well is///Go...
# 978                  None
# 1011  ADCP only availa...
# 1012                 None
# 1013                 None
# 1014  Position, speed,...
# 1015  Position, speed,...
# 1016  Position, speed,...
# 1027  see uskess.org//...
# 1042  extended pattern...
# 1043  extended pattern...
# 1044  extended pattern...
# 1045                 good
# 1046                 good
# 1047  extended pattern...
# 1048  extended pattern...
# 1049  Jordan completed...
# 1050                 good
# 1051                 None
# 1052                 None
# 1053                 None
# 1054                 good
# 1055                 good
# 1056                 good
# 1057  extended pattern...
# 1058  extended pattern...
# 1059  extended pattern...
# 1060  xducer in fresh ...
# 1061  xducer in fresh ...
# 1062  Data from the st...
# 1063  xducer in fresh ...
# 1064  Bad weather towa...
# 1065                 good
# 1066  xducer in fresh ...
# 1067  xducer in fresh ...
# 1068                 None
# 1069  There is a 6 day...
# 1070  xducer in fresh ...
# 1071  xducer in fresh ...
# 1072  Ashtech failed o...
# 1073  xducer in fresh ...
# 1074  There were gaps ...
# 1075  xducer in fresh ...
# 1076  xducer in fresh ...
# 1077  xducer in fresh ...
# 1135        No POSM used.
# 1136        No POSM used.
# 1137                 None
# 1138                 None
# 1220  ADCP missing 3-6...
# 1227  The well is///ex...
# 1289                   OK
# 1290                   OK
# 1291                   OK
# 1292                   OK
# 1302                 None
# 1316  There were 3 cru...
# 1317  There were 3 cru...
# 1318  There were 3 cru...
# 1484  single-ping data...
# 1638   no change to phase
# 1639  no change to pha...
# 1974  The orientation ...
# 2015  POSMV poor quali...
# 2078  The orientation ...
# 2081  The orientation ...
# 2082  The orientation ...
# 2087  The orientation ...
# 2088  The orientation ...
# 2101  The orientation ...
# 2102  The orientation ...
# 2103  The orientation ...
# 2107  The orientation ...
# 2139  The orientation ...
# 2140  The orientation ...
# 2141  The orientation ...
# 2144  The orientation ...
# 2151  The orientation ...
# 2158  The orientation ...
# 2159  The orientation ...
# 2267  Route varies dur...
# 2268  Route varies dur...
# 2269  Route varies dur...
# 2270  Route varies dur...
# 2271  Route varies dur...
# 2272  Route varies dur...
# 2273  Route varies dur...
# 2274  Route varies dur...
# 2275  Route varies dur...
# 2276  Route varies dur...

# %%
# - Testing the idea that WH-300 is ALL broadband
#df[(df['instrument_name']=='Workhorse-300')][
#    ['fname','bw_from_all_text','bw_from_comments','bw_from_hardware_model','bw_from_transmit_frequency','bandwidth']]
#df[(df['instrument_name']=='Workhorse-300') & (df['bandwidth'].notnull())][
#    ['fname','bw_from_all_text','bw_from_comments','bw_from_hardware_model','bw_from_transmit_frequency','bandwidth']]
# --> only 2 are narrowband (lots of None though); discovered that there are 2 problematic nc files
# (02095_short.nc, 02125_short.nc) that say in one comments
# section that WH-300 is narrowband and in another that it's broadband, but I think they made a mistake
# saying it's narrowband; I also checked for pingtype = bb in the post cruise processing notes; these 2 files had that!
# I think that means they are both broadband and/or that was even assumed in the post cruise processing
# --> MANUALLY OVERWRITE BANDWIDTH FOR THESE 2 FILES (or just make all WH-300 bb, we'll see)
# --> search for 'pingtype = bb' in all_text
#df[df['all_text'].str.contains('pingtype')][['fname','instrument_name','bandwidth']]

# - What about those WH-300 that still don't have bandwidth after bw_from_all_text?
print(len(df[(df['instrument_name']=='Workhorse-300') & ~(df['bandwidth'].notnull()) & ~(df['bw_from_all_text'].notnull())]))
print(len(df[(df['instrument_name']=='Workhorse-300') & ~(df['bandwidth'].notnull()) & ~(df['bw_from_all_text'].notnull()) & 
      df['all_text'].str.contains('pingtype')]))
print(len(df[~(df['bandwidth'].notnull()) & ~(df['bw_from_all_text'].notnull()) & df['all_text'].str.contains('pingtype')]))
df[(df['instrument_name']=='Workhorse-300') & ~(df['bandwidth'].notnull()) & ~(df['bw_from_all_text'].notnull())][
    ['fname','bw_from_all_text','bw_from_comments','bw_from_hardware_model','bw_from_transmit_frequency','bandwidth']]
# Out:
# 18
# 4
# 5
#                fname bw_from_all_text bw_from_comments bw_from_hardware_model  \
# 1484  01568_short.nc             None             None                 None
# 1974  02086_short.nc             None             None                 None
# 2078  02191_short.nc             None             None                 None
# 2081  02194_short.nc             None             None                 None
# 2082  02195_short.nc             None             None                 None
# 2087  02200_short.nc             None             None                 None
# 2088  02201_short.nc             None             None                 None
# 2101  02214_short.nc             None             None                 None
# 2102  02215_short.nc             None             None                 None
# 2103  02216_short.nc             None             None                 None
# 2107  02220_short.nc             None             None                 None
# 2139  02258_short.nc             None             None                 None
# 2140  02259_short.nc             None             None                 None
# 2141  02261_short.nc             None             None                 None
# 2144  02265_short.nc             None             None                 None
# 2151  02272_short.nc             None             None                 None
# 2158  02281_short.nc             None             None                 None
# 2159  02282_short.nc             None             None                 None
#
#      bw_from_transmit_frequency bandwidth
# 1484                 None            None
# 1974                 None            None
# 2078                 None            None
# 2081                 None            None
# 2082                 None            None
# 2087                 None            None
# 2088                 None            None
# 2101                 None            None
# 2102                 None            None
# 2103                 None            None
# 2107                 None            None
# 2139                 None            None
# 2140                 None            None
# 2141                 None            None
# 2144                 None            None
# 2151                 None            None
# 2158                 None            None
# 2159                 None            None

# %%
#pd.set_option('max_rows', 1000)
#pd.set_option('display.max_colwidth', -1)
#df.head()

# %% [markdown]
# ## Uniformly rename hardware_model names

# %%
# - Save out all unique hardware_model names + # of occurrences to look at in separate window
# --> use this output to create the legend below of how to translate different instrument names to a uniform list of names
#df['hardware_model'].value_counts().to_csv('jasadcp_unique_instruments.csv', header=['hardware_model count'])

# %% [markdown]
# #### **List of uniform instrument names:**
#
# **All names to become 'OS-38'**:\
# 'Ocean Surveyer 38', 'Ocean Surveyor 38'
#
# **All names to become 'OS-75'**:\
# 'Ocean Surveyor 75', 'OS75 narrowband', 'Ocean Surveyer 75', 'Ocean Surveyor 75 narrowband', 'OS75 (Ocean Surveyor)', 'Ocean Surveyor 75 broadband', 'Ocean Surveyor OS75', 'OS75', 'Ocean Surveryor 75', 'Ocean Surveyor 75 narroband', 'Ocean Surveyor 75 Broadband', 'Ocean Surveyor 75 Narrowband', '75KHz Ocean Surveyor narrowband', 'Ocean Surveyor 75 kHz', 'RDI 75KHz Ocean Surveyor', 'Ocean Surveyor 75 kHz Phased Array', '75KHz Ocean Surveyor'
#
# **All names to become 'OS-150'**:\
# 'Ocean Surveyer 150', 'Ocean Surveryor 150', 'Ocean Surveyor 150 narroband', 'Ocean Surveyor 150 narrowband', 'Ocean Surveyor 150 broadband'
#
# **All names to become 'OS-II-38'**:\
# 'Ocean Surveyor II (OS-II 38)'
#
# **All names to become 'OS-II-75'**:\
# 'OSII75S phased-array'
#
# **All names to become 'WH-300'**:\
# 'WorkHorse 300', 'Workhorse 300', 'Workhorse 300; 300 kHz'
#
# **All names to become 'WH-1200'**:\
# 'Workhorse 1200'
#
# **All names to become 'WH-Mariner-300'**:\
# 'Workhorse Mariner (300 kHz)'
#
# **All names to become 'WH-Mariner-600'**:\
# 'WorkHorse Mariner 600'
#
# **All names to become 'DCP4400A'**:\
# 'DCP4400A'
#
# **All names to become NB-VM-75:**\
# 'narrowband 75 kHz' (assume VM), 'VM75 narrowband'
#
# **All names to become NB-VM-150:**\
# 'Narrowband 150' (assume VM), 'NB 150' (assume VM), '150 narrowband' (assume VM), '150 kHz Narrowband' (assume VM), 'Vessel-mounted 150 kHz Narrowband' (HAS ALL SERIAL NUMBERS), 'Narrow Band 150Khz' (assume VM), 'Vessel-mount 150 kHz Narrowband', '1) Narrow Band 150 kHz' (assume VM), '150 kHz narrow band' (assume VM), 'Vessel-Mount 150 kHz Narrowband' (HAS ALL SERIAL NUMBERS), 'VM-150 Narrowband', 'RD-VM150 Narrow band', 'VM-150 (NB)', 'VM-150 narrowband', 'RDI VM150 narrowband', 'RD-VM150 narrowband', 'NB 150 (VM-150-18HP)' (assume 18HP makes no difference)
#
# **All names to become NB-VM-300:**\
# 'Narrowband 300' (assume VM), '300 narrow band' (assume VM)
#
# **All names to become NB-DR-150:**\
# 'Direct-Read 150 kHz Narrowband' (HAS ALL SERIAL NUMBERS)
#
# **All names to become BB-VM-150:**\
# 'Broadband 150' (assume VM),  'Broad Band 150' (assume VM), '150 kHz broadband' (assume VM), '"150 broad band, concave"' (assume VM)
#
# -----The following are mildly annoying:
# **All names to become 'VM-150'**:\
# 'VM-150', 'RD-VM150', 'VM150', 'RD-VM0150'
#
# **All names to become 'VM-300'**:\
# 'VM-300', 'RD-VM300'
#
# **All names to become 'UNCLEAR'**:\
# '150', 'RDI', '150 kHz hull mounted ADCP', 'Narrowband', '150 kHz', '153.6 kHz hull mounted ADCP'
#
# **Special cases**:\
# 1.) 'RD-VM' (HAS ALL SERIAL NUMBERS, READ TRANSMIT FREQUENCY, TOO - IF 150 THEN VM-150, ETC.)
# 2.) 'VM-150 and VM-300' (CHECKED NC FILES - CAN'T DTMN IF IT'S 150 OR 300 --> DISCARD)

# %%
# - Define fxn to uniformly rename different original hardware_model names
def set_uniform_name_orig_hardware_model(row):
    if row['hardware_model']:
        if row['hardware_model']=='DCP4400A':
            return 'DCP4400A'
        elif row['hardware_model'] in ['Ocean Surveyer 38', 'Ocean Surveyor 38']:
            return 'OS-38' 
        elif row['hardware_model'] in ['Ocean Surveyor 75', 'OS75 narrowband',
                                       'Ocean Surveyer 75', 'Ocean Surveyor 75 narrowband',
                                       'OS75 (Ocean Surveyor)', 'Ocean Surveyor 75 broadband',
                                       'Ocean Surveyor OS75', 'OS75', 'Ocean Surveryor 75',
                                       'Ocean Surveyor 75 narroband', 'Ocean Surveyor 75 Broadband',
                                       'Ocean Surveyor 75 Narrowband', '75KHz Ocean Surveyor narrowband',
                                       'Ocean Surveyor 75 kHz', 'RDI 75KHz Ocean Surveyor',
                                       'Ocean Surveyor 75 kHz Phased Array', '75KHz Ocean Surveyor']:
            return 'OS-75' 
        elif row['hardware_model'] in ['Ocean Surveyer 150', 'Ocean Surveryor 150',
                                       'Ocean Surveyor 150 narroband', 'Ocean Surveyor 150 narrowband',
                                       'Ocean Surveyor 150 broadband']:
            return 'OS-150'
        elif row['hardware_model'] in ['Ocean Surveyor II (OS-II 38)']:
            return 'OS-II-38'
        elif row['hardware_model'] in ['OSII75S phased-array']:
            return 'OS-II-75'
        elif row['hardware_model'] in ['VM75 narrowband']:
            return 'VM-75'
        elif row['hardware_model'] in ['VM-150', 'RD-VM150', 'VM-150 Narrowband', 'RD-VM150 Narrow band',
                                       'VM-150 (NB)', 'VM-150 narrowband', 'RDI VM150 narrowband',
                                       'VM150', 'RD-VM150 narrowband', 'RD-VM0150']:
            return 'VM-150'
        elif row['hardware_model'] in ['VM-300', 'RD-VM300']:
            return 'VM-300'
        elif row['hardware_model'] in ['RD-VM']:
            if re.search('150', row['transmit_frequency']):
                return 'VM-150'
        elif row['hardware_model'] in ['NB 150 (VM-150-18HP)']:
            return 'VM-150-18HP'
        elif row['hardware_model'] in ['WorkHorse 300', 'Workhorse 300', 'Workhorse 300; 300 kHz']:
            return 'Workhorse-300'
        elif row['hardware_model'] in ['Workhorse 1200']:
            return 'Workhorse-1200'
        elif row['hardware_model'] in ['Workhorse Mariner (300 kHz)']:
            return 'Workhorse-Mariner-300'
        elif row['hardware_model'] in ['WorkHorse Mariner 600']:
            return 'Workhorse-Mariner-600'
        else:
            return 'ZUNCLEAR: ' + row['hardware_model']
    else:
        return None

# %%
# - Create df w/ uniform instrument names
df['instrument_name']=df.apply(set_uniform_name_orig_hardware_model, axis=1)
cols = list(df.columns.values)
cols = cols[0:2]+['instrument_name']+cols[2:-1]
df = df[cols]

# %%
# - Get rid of NULL instrument_name rows (there's only 1 and it has no other info)
# and 'ZUNCLEAR: VM-150 and VM-300' rows
df = df[~df['instrument_name'].isnull()]
df = df[~(df['instrument_name']=='ZUNCLEAR: VM-150 and VM-300')]

# %%
# - Get rid of columns not needed anymore
df.drop(columns=['bw_from_comments','bw_from_hardware_model',
                 'bw_from_transmit_frequency'], inplace=True)

# %%
# pacific only
#01285 - 1st HOTS w/ NB150 in 2005!!
#01287
#01289
#01291
#01527
#01528
#02131
#02133
#02135
#02137
#
# southern ocean
#02111
#
#00803
#00805
